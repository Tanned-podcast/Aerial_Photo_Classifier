# %%
import datetime
dt_now = datetime.datetime.now()
print(dt_now.strftime('%Y%m%d_%H%M'))
# Out:
# 20241023_1511

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import torch
import numpy as np
print(np.array(torch.tensor([1])))
# Out:
# [1]

# %%
#PyTorchはモデルの最終レイヤに損失関数とsoftmaxが入っていない loss_fnに入っているのでカスタム可能
import torch
from torchinfo import summary
import torchvision.models as models
import torch.nn as nn

resnet50 = models.resnet50(weights='DEFAULT')


resnet50.conv1 = torch.nn.Conv2d(3,64,kernel_size = (7,7),stride = (2,2), padding = (3,3), bias = False)
num_ftrs = resnet50.fc.in_features
#modifying final layer
resnet50.fc = nn.Linear(num_ftrs,2)
summary(model=resnet50, input_size=(8, 3, 16, 16))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ResNet                                   [8, 2]                    --
# ├─Conv2d: 1-1                            [8, 64, 8, 8]             9,408
# ├─BatchNorm2d: 1-2                       [8, 64, 8, 8]             128
# ├─ReLU: 1-3                              [8, 64, 8, 8]             --
# ├─MaxPool2d: 1-4                         [8, 64, 4, 4]             --
# ├─Sequential: 1-5                        [8, 256, 4, 4]            --
# │    └─Bottleneck: 2-1                   [8, 256, 4, 4]            --
# │    │    └─Conv2d: 3-1                  [8, 64, 4, 4]             4,096
# │    │    └─BatchNorm2d: 3-2             [8, 64, 4, 4]             128
# │    │    └─ReLU: 3-3                    [8, 64, 4, 4]             --
# │    │    └─Conv2d: 3-4                  [8, 64, 4, 4]             36,864
# │    │    └─BatchNorm2d: 3-5             [8, 64, 4, 4]             128
# │    │    └─ReLU: 3-6                    [8, 64, 4, 4]             --
# │    │    └─Conv2d: 3-7                  [8, 256, 4, 4]            16,384
# │    │    └─BatchNorm2d: 3-8             [8, 256, 4, 4]            512
# │    │    └─Sequential: 3-9              [8, 256, 4, 4]            16,896
# │    │    └─ReLU: 3-10                   [8, 256, 4, 4]            --
# │    └─Bottleneck: 2-2                   [8, 256, 4, 4]            --
# │    │    └─Conv2d: 3-11                 [8, 64, 4, 4]             16,384
# │    │    └─BatchNorm2d: 3-12            [8, 64, 4, 4]             128
# │    │    └─ReLU: 3-13                   [8, 64, 4, 4]             --
# │    │    └─Conv2d: 3-14                 [8, 64, 4, 4]             36,864
# │    │    └─BatchNorm2d: 3-15            [8, 64, 4, 4]             128
# │    │    └─ReLU: 3-16                   [8, 64, 4, 4]             --
# │    │    └─Conv2d: 3-17                 [8, 256, 4, 4]            16,384
# │    │    └─BatchNorm2d: 3-18            [8, 256, 4, 4]            512
# │    │    └─ReLU: 3-19                   [8, 256, 4, 4]            --
# │    └─Bottleneck: 2-3                   [8, 256, 4, 4]            --
# │    │    └─Conv2d: 3-20                 [8, 64, 4, 4]             16,384
# │    │    └─BatchNorm2d: 3-21            [8, 64, 4, 4]             128
# │    │    └─ReLU: 3-22                   [8, 64, 4, 4]             --
# │    │    └─Conv2d: 3-23                 [8, 64, 4, 4]             36,864
# │    │    └─BatchNorm2d: 3-24            [8, 64, 4, 4]             128
# │    │    └─ReLU: 3-25                   [8, 64, 4, 4]             --
# │    │    └─Conv2d: 3-26                 [8, 256, 4, 4]            16,384
# │    │    └─BatchNorm2d: 3-27            [8, 256, 4, 4]            512
# │    │    └─ReLU: 3-28                   [8, 256, 4, 4]            --
# ├─Sequential: 1-6                        [8, 512, 2, 2]            --
# │    └─Bottleneck: 2-4                   [8, 512, 2, 2]            --
# │    │    └─Conv2d: 3-29                 [8, 128, 4, 4]            32,768
# │    │    └─BatchNorm2d: 3-30            [8, 128, 4, 4]            256
# │    │    └─ReLU: 3-31                   [8, 128, 4, 4]            --
# │    │    └─Conv2d: 3-32                 [8, 128, 2, 2]            147,456
# │    │    └─BatchNorm2d: 3-33            [8, 128, 2, 2]            256
# │    │    └─ReLU: 3-34                   [8, 128, 2, 2]            --
# │    │    └─Conv2d: 3-35                 [8, 512, 2, 2]            65,536
# │    │    └─BatchNorm2d: 3-36            [8, 512, 2, 2]            1,024
# │    │    └─Sequential: 3-37             [8, 512, 2, 2]            132,096
# │    │    └─ReLU: 3-38                   [8, 512, 2, 2]            --
# │    └─Bottleneck: 2-5                   [8, 512, 2, 2]            --
# │    │    └─Conv2d: 3-39                 [8, 128, 2, 2]            65,536
# │    │    └─BatchNorm2d: 3-40            [8, 128, 2, 2]            256
# │    │    └─ReLU: 3-41                   [8, 128, 2, 2]            --
# │    │    └─Conv2d: 3-42                 [8, 128, 2, 2]            147,456
# │    │    └─BatchNorm2d: 3-43            [8, 128, 2, 2]            256
# │    │    └─ReLU: 3-44                   [8, 128, 2, 2]            --
# │    │    └─Conv2d: 3-45                 [8, 512, 2, 2]            65,536
# │    │    └─BatchNorm2d: 3-46            [8, 512, 2, 2]            1,024
# │    │    └─ReLU: 3-47                   [8, 512, 2, 2]            --
# │    └─Bottleneck: 2-6                   [8, 512, 2, 2]            --
# │    │    └─Conv2d: 3-48                 [8, 128, 2, 2]            65,536
# │    │    └─BatchNorm2d: 3-49            [8, 128, 2, 2]            256
# │    │    └─ReLU: 3-50                   [8, 128, 2, 2]            --
# │    │    └─Conv2d: 3-51                 [8, 128, 2, 2]            147,456
# │    │    └─BatchNorm2d: 3-52            [8, 128, 2, 2]            256
# │    │    └─ReLU: 3-53                   [8, 128, 2, 2]            --
# │    │    └─Conv2d: 3-54                 [8, 512, 2, 2]            65,536
# │    │    └─BatchNorm2d: 3-55            [8, 512, 2, 2]            1,024
# │    │    └─ReLU: 3-56                   [8, 512, 2, 2]            --
# │    └─Bottleneck: 2-7                   [8, 512, 2, 2]            --
# │    │    └─Conv2d: 3-57                 [8, 128, 2, 2]            65,536
# │    │    └─BatchNorm2d: 3-58            [8, 128, 2, 2]            256
# │    │    └─ReLU: 3-59                   [8, 128, 2, 2]            --
# │    │    └─Conv2d: 3-60                 [8, 128, 2, 2]            147,456
# │    │    └─BatchNorm2d: 3-61            [8, 128, 2, 2]            256
# │    │    └─ReLU: 3-62                   [8, 128, 2, 2]            --
# │    │    └─Conv2d: 3-63                 [8, 512, 2, 2]            65,536
# │    │    └─BatchNorm2d: 3-64            [8, 512, 2, 2]            1,024
# │    │    └─ReLU: 3-65                   [8, 512, 2, 2]            --
# ├─Sequential: 1-7                        [8, 1024, 1, 1]           --
# │    └─Bottleneck: 2-8                   [8, 1024, 1, 1]           --
# │    │    └─Conv2d: 3-66                 [8, 256, 2, 2]            131,072
# │    │    └─BatchNorm2d: 3-67            [8, 256, 2, 2]            512
# │    │    └─ReLU: 3-68                   [8, 256, 2, 2]            --
# │    │    └─Conv2d: 3-69                 [8, 256, 1, 1]            589,824
# │    │    └─BatchNorm2d: 3-70            [8, 256, 1, 1]            512
# │    │    └─ReLU: 3-71                   [8, 256, 1, 1]            --
# │    │    └─Conv2d: 3-72                 [8, 1024, 1, 1]           262,144
# │    │    └─BatchNorm2d: 3-73            [8, 1024, 1, 1]           2,048
# │    │    └─Sequential: 3-74             [8, 1024, 1, 1]           526,336
# │    │    └─ReLU: 3-75                   [8, 1024, 1, 1]           --
# │    └─Bottleneck: 2-9                   [8, 1024, 1, 1]           --
# │    │    └─Conv2d: 3-76                 [8, 256, 1, 1]            262,144
# │    │    └─BatchNorm2d: 3-77            [8, 256, 1, 1]            512
# │    │    └─ReLU: 3-78                   [8, 256, 1, 1]            --
# │    │    └─Conv2d: 3-79                 [8, 256, 1, 1]            589,824
# │    │    └─BatchNorm2d: 3-80            [8, 256, 1, 1]            512
# │    │    └─ReLU: 3-81                   [8, 256, 1, 1]            --
# │    │    └─Conv2d: 3-82                 [8, 1024, 1, 1]           262,144
# │    │    └─BatchNorm2d: 3-83            [8, 1024, 1, 1]           2,048
# │    │    └─ReLU: 3-84                   [8, 1024, 1, 1]           --
# │    └─Bottleneck: 2-10                  [8, 1024, 1, 1]           --
# │    │    └─Conv2d: 3-85                 [8, 256, 1, 1]            262,144
# │    │    └─BatchNorm2d: 3-86            [8, 256, 1, 1]            512
# │    │    └─ReLU: 3-87                   [8, 256, 1, 1]            --
# │    │    └─Conv2d: 3-88                 [8, 256, 1, 1]            589,824
# │    │    └─BatchNorm2d: 3-89            [8, 256, 1, 1]            512
# │    │    └─ReLU: 3-90                   [8, 256, 1, 1]            --
# │    │    └─Conv2d: 3-91                 [8, 1024, 1, 1]           262,144
# │    │    └─BatchNorm2d: 3-92            [8, 1024, 1, 1]           2,048
# │    │    └─ReLU: 3-93                   [8, 1024, 1, 1]           --
# │    └─Bottleneck: 2-11                  [8, 1024, 1, 1]           --
# │    │    └─Conv2d: 3-94                 [8, 256, 1, 1]            262,144
# │    │    └─BatchNorm2d: 3-95            [8, 256, 1, 1]            512
# │    │    └─ReLU: 3-96                   [8, 256, 1, 1]            --
# │    │    └─Conv2d: 3-97                 [8, 256, 1, 1]            589,824
# │    │    └─BatchNorm2d: 3-98            [8, 256, 1, 1]            512
# │    │    └─ReLU: 3-99                   [8, 256, 1, 1]            --
# │    │    └─Conv2d: 3-100                [8, 1024, 1, 1]           262,144
# │    │    └─BatchNorm2d: 3-101           [8, 1024, 1, 1]           2,048
# │    │    └─ReLU: 3-102                  [8, 1024, 1, 1]           --
# │    └─Bottleneck: 2-12                  [8, 1024, 1, 1]           --
# │    │    └─Conv2d: 3-103                [8, 256, 1, 1]            262,144
# │    │    └─BatchNorm2d: 3-104           [8, 256, 1, 1]            512
# │    │    └─ReLU: 3-105                  [8, 256, 1, 1]            --
# │    │    └─Conv2d: 3-106                [8, 256, 1, 1]            589,824
# │    │    └─BatchNorm2d: 3-107           [8, 256, 1, 1]            512
# │    │    └─ReLU: 3-108                  [8, 256, 1, 1]            --
# │    │    └─Conv2d: 3-109                [8, 1024, 1, 1]           262,144
# │    │    └─BatchNorm2d: 3-110           [8, 1024, 1, 1]           2,048
# │    │    └─ReLU: 3-111                  [8, 1024, 1, 1]           --
# │    └─Bottleneck: 2-13                  [8, 1024, 1, 1]           --
# │    │    └─Conv2d: 3-112                [8, 256, 1, 1]            262,144
# │    │    └─BatchNorm2d: 3-113           [8, 256, 1, 1]            512
# │    │    └─ReLU: 3-114                  [8, 256, 1, 1]            --
# │    │    └─Conv2d: 3-115                [8, 256, 1, 1]            589,824
# │    │    └─BatchNorm2d: 3-116           [8, 256, 1, 1]            512
# │    │    └─ReLU: 3-117                  [8, 256, 1, 1]            --
# │    │    └─Conv2d: 3-118                [8, 1024, 1, 1]           262,144
# │    │    └─BatchNorm2d: 3-119           [8, 1024, 1, 1]           2,048
# │    │    └─ReLU: 3-120                  [8, 1024, 1, 1]           --
# ├─Sequential: 1-8                        [8, 2048, 1, 1]           --
# │    └─Bottleneck: 2-14                  [8, 2048, 1, 1]           --
# │    │    └─Conv2d: 3-121                [8, 512, 1, 1]            524,288
# │    │    └─BatchNorm2d: 3-122           [8, 512, 1, 1]            1,024
# │    │    └─ReLU: 3-123                  [8, 512, 1, 1]            --
# │    │    └─Conv2d: 3-124                [8, 512, 1, 1]            2,359,296
# │    │    └─BatchNorm2d: 3-125           [8, 512, 1, 1]            1,024
# │    │    └─ReLU: 3-126                  [8, 512, 1, 1]            --
# │    │    └─Conv2d: 3-127                [8, 2048, 1, 1]           1,048,576
# │    │    └─BatchNorm2d: 3-128           [8, 2048, 1, 1]           4,096
# │    │    └─Sequential: 3-129            [8, 2048, 1, 1]           2,101,248
# │    │    └─ReLU: 3-130                  [8, 2048, 1, 1]           --
# │    └─Bottleneck: 2-15                  [8, 2048, 1, 1]           --
# │    │    └─Conv2d: 3-131                [8, 512, 1, 1]            1,048,576
# │    │    └─BatchNorm2d: 3-132           [8, 512, 1, 1]            1,024
# │    │    └─ReLU: 3-133                  [8, 512, 1, 1]            --
# │    │    └─Conv2d: 3-134                [8, 512, 1, 1]            2,359,296
# │    │    └─BatchNorm2d: 3-135           [8, 512, 1, 1]            1,024
# │    │    └─ReLU: 3-136                  [8, 512, 1, 1]            --
# │    │    └─Conv2d: 3-137                [8, 2048, 1, 1]           1,048,576
# │    │    └─BatchNorm2d: 3-138           [8, 2048, 1, 1]           4,096
# │    │    └─ReLU: 3-139                  [8, 2048, 1, 1]           --
# │    └─Bottleneck: 2-16                  [8, 2048, 1, 1]           --
# │    │    └─Conv2d: 3-140                [8, 512, 1, 1]            1,048,576
# │    │    └─BatchNorm2d: 3-141           [8, 512, 1, 1]            1,024
# │    │    └─ReLU: 3-142                  [8, 512, 1, 1]            --
# │    │    └─Conv2d: 3-143                [8, 512, 1, 1]            2,359,296
# │    │    └─BatchNorm2d: 3-144           [8, 512, 1, 1]            1,024
# │    │    └─ReLU: 3-145                  [8, 512, 1, 1]            --
# │    │    └─Conv2d: 3-146                [8, 2048, 1, 1]           1,048,576
# │    │    └─BatchNorm2d: 3-147           [8, 2048, 1, 1]           4,096
# │    │    └─ReLU: 3-148                  [8, 2048, 1, 1]           --
# ├─AdaptiveAvgPool2d: 1-9                 [8, 2048, 1, 1]           --
# ├─Linear: 1-10                           [8, 2]                    4,098
# ==========================================================================================
# Total params: 23,512,130
# Trainable params: 23,512,130
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 253.79
# ==========================================================================================
# Input size (MB): 0.02
# Forward/backward pass size (MB): 8.29
# Params size (MB): 94.05
# Estimated Total Size (MB): 102.36
# ==========================================================================================

# %%
import torch
import torch.nn as nn

# モデルの出力（予測された確率）
output = torch.randn(1, requires_grad=True)  # 例えば、モデルの出力をランダムに生成

# 正解ラベル（0または1）
target = torch.tensor([1.0])  # 例えば、1のラベル

# BCE損失を計算
loss_fn = nn.BCELoss()
loss = loss_fn(torch.sigmoid(output), target)

print("BCE Loss:", loss.item())
# Out:
# BCE Loss: 0.6826429963111877

# %%
import torch
import numpy as np
input=torch.randn(8,2)
print(input.size())
print(input)
output=torch.zeros(input.size()[0])
print(np.argmax((input[0])))
output[:]=np.argmax(input[:])
print(output.size)
print(output)
# Out:
# torch.Size([8, 2])
# tensor([[ 0.6020,  1.4872],
#         [ 0.7111,  1.0773],
#         [ 0.4446, -1.0869],
#         [ 0.1941,  0.4522],
#         [ 0.2885,  1.4588],
#         [-1.2686, -0.6088],
#         [ 1.4295,  0.9408],
#         [-0.0063, -0.1055]])
# tensor(1)
# <built-in method size of Tensor object at 0x00000136A264B110>
# tensor([1., 1., 1., 1., 1., 1., 1., 1.])

# %%
import glob
import os
import numpy as np
import torch
import torch.optim as optim
import torchvision.transforms.functional as TF
from torchvision.transforms import v2
import torchvision.models as models
import torch.nn as nn
import cv2
from torch.utils.data import Dataset
from pathlib import Path
from typing import List, Tuple
from torch.utils.data import DataLoader
from torch.utils.data import random_split
import matplotlib.pyplot as plt
import datetime
import pandas as pd
import seaborn as sns; sns.set() # sns.set() ==> グラフの見た目をseabornに合わせる
# %matplotlib inline

time = datetime.datetime.now()
filedate=time.strftime('%Y%m%d_%H%M')

device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('cpu')

Channels=3
batch_size=8
epochs=120
IMG_SIZE=224
valsplit=0.25

Classes = ["Damage", "NoDamage"]
ClassNum = len(Classes)

trainpath=r"C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\Train_SameSize"
savepath=r"C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\Weights"
historypath=r"C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\History"

'''
PytorchではDataloaderという,膨大なデータセットからでもメモリを圧迫せずに取り出せてforループにも対応するための枠組みがある
データセットをDataloaderが引っ張ってこれるような形式にするためにMyDataset(torch.utils.data.Dataset)というクラスを作れば，
あとはそのメソッドをtorch.utils.data.Datasetが勝手に使用してデータを加工してくれる
__init__, __getitem__, __len__をクラス内で必ず定義しなければならない
Dataloader内のデータはバッチごとにまとめられる
'''
class MyDataset(Dataset):
    def __init__(self, root: str, transforms, Classes) -> None:
        super().__init__()
        self.transforms = transforms
        self.Classes = Classes
        #globは複数のファイルのパスをまとめて取得する
        #訓練と訓練白黒の二個下のディレクトリから画像を取得
        self.data = list(sorted(Path(root).glob("*\*")))


    # ここで取り出すデータを指定している
    def __getitem__(self, index: int) -> Tuple[torch.Tensor, torch.Tensor]:
        data = self.data[index]
        #OpenCVで読み込むときは必ずRGBに変換
        img1 = cv2.cvtColor(cv2.imread(str(data)), cv2.COLOR_BGR2RGB)
        img1 = cv2.resize(img1, (IMG_SIZE, IMG_SIZE))
        img1 = TF.to_tensor(img1)

        # データの変形 (transforms)
        transformed_img = self.transforms(img1)

        #ラベル貼り：dataというパスを/で区切ってリストにし，クラス名のところをラベルに格納
        #クラス名は文字列なので，self.Classesの要素と比較して一致するところの番号をラベルとする
        label = str(data).split("\\")[-2]
        label = torch.tensor(self.Classes.index(label))

        return transformed_img, label

    # この method がないと DataLoader を呼び出す際にエラーを吐かれる
    def __len__(self) -> int:
        return len(self.data)


#入力データに施す処理
transforms = v2.Compose([
        v2.RandomHorizontalFlip(p=0.5),
        v2.ToDtype(torch.float32, scale=True),
        v2.Normalize(mean=[0,0,0], std=[0.2, 0.2, 0.2]),
])


trainvalset = MyDataset(root=trainpath, transforms=transforms, Classes=Classes)
trainset, valset = random_split(trainvalset, [1-valsplit, valsplit])

trainloader = DataLoader(dataset=trainset,batch_size=batch_size,shuffle=True)
valloader = DataLoader(dataset=valset,batch_size=batch_size,shuffle=True)


resnet50 = models.resnet50(weights='DEFAULT')


resnet50.conv1 = torch.nn.Conv2d(Channels,64,kernel_size = (7,7),stride = (2,2), padding = (3,3), bias = False)
num_ftrs = resnet50.fc.in_features
#modifying final layer
resnet50.fc = nn.Linear(num_ftrs,ClassNum)

#GPUにニューラルネットワークを渡す
resnet50=resnet50.to(device)

#lossfunction&optimizer
#二値なのでBinaryCrossEntropy

loss_fn = nn.CrossEntropyLoss()
optimizer = optim.SGD(resnet50.parameters(), lr=0.001, momentum=0.9)

print("Device:", device, "IMGSIZE:(", Channels, IMG_SIZE, IMG_SIZE, ")",  "BatchSize:", batch_size, "Epochs:", epochs, "Valsplit:", valsplit, "Class:", Classes, "Final Layer Nodes:", num_ftrs)

'''
trainiterator
enumerateはtrainloader内のすべてのdataに対してループし，繰り返し回数をbatchに渡すという意味
Dataloader内ではバッチごとにデータがまとめられるので1回の取り出しで1バッチ分のデータを丸々取り出せる
'''
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

def train(trainloader, valloader, model, loss_fn, optimizer, epochs):
    size = len(trainloader.dataset)
    num_batches = len(trainloader)
    size_val = len(valloader.dataset)
    num_batches_val = len(valloader)
    print("TrainData Size:", size, "TrainData Batches", num_batches, "ValData Size:", size_val, "ValData Batches:", num_batches_val)
    for epoch in range(epochs):
        running_loss, running_correct = 0, 0
        val_loss, val_correct = 0, 0
        for batch, (X, y) in enumerate(trainloader):
            X=X.to(device)
            y=y.to(device)
            # Compute prediction and loss
            pred = model(X)
            loss = loss_fn(torch.sigmoid(pred), y)

            # Backpropagation
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

            #損失と正解数の合計を計算しておき，後でそのエポック内での平均をとる
            running_loss += loss.item()
            running_correct += (pred.argmax(1) == y).type(torch.float).sum().item()

        epoch_loss = running_loss / num_batches
        epoch_acc = running_correct / size

        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_acc)

        print(f'Epoch {epoch + 1} TrainLoss: {epoch_loss:.4f} TrainAcc: {epoch_acc:.4f}')

        # Set the model to evaluation mode - important for batch normalization and dropout layers
        model.eval()
        # Evaluating the model with torch.no_grad() ensures that no gradients are computed during test mode
        # also serves to reduce unnecessary gradient computations and memory usage for tensors with requires_grad=True
        with torch.no_grad():
            for X, y in valloader:
                X=X.to(device)
                y=y.to(device)
                pred = model(X)
                val_loss += loss_fn(torch.sigmoid(pred), y).item()
                val_correct += (pred.argmax(1) == y).type(torch.float).sum().item()

            val_loss /= num_batches_val
            val_correct /= size_val
        # Set the model to train mode
        model.train()

        val_losses.append(val_loss)
        val_accuracies.append(val_correct)

        print(f'Epoch {epoch + 1} ValLoss: {val_loss:.4f} ValAcc: {val_correct:.4f}')

        #10epoch毎にパラメータを別々のフォルダに保存
        e1=epoch+1
        if (e1 % 10 == 0):
            savepath2 = Path(savepath+"\\"+str(e1)+"\model_weights"+filedate+".pth")
            print('Saving Model...')
            torch.save(model.state_dict(), savepath2)
            print('Model saved in', savepath2)

        print(' ')

train(trainloader, valloader, resnet50, loss_fn, optimizer, epochs)

#グラフ可視化
#pltの(x,y)のxにあたるepochのリスト　1から開始
ep=np.arange(1, epochs+1)

#グラフにプロットする正解率と損失のリストをCSVに書き出し to_csvは新規フォルダを作ってくれないのでosで作る
historypath2 = str(Path(historypath+"\\"+filedate))
os.mkdir(historypath2)
pd.DataFrame(data=np.array([ep, train_accuracies]).T, columns=["Epoch", "Accuracy"]).to_csv(Path(historypath2+"\\"+"Train_Acc.csv"))
pd.DataFrame(data=np.array([ep, train_losses]).T, columns=["Epoch", "Loss"]).to_csv(Path(historypath2+"\\"+"Train_Loss.csv"))
pd.DataFrame(data=np.array([ep, val_accuracies]).T, columns=["Epoch", "Accuracy"]).to_csv(Path(historypath2+"\\"+"Val_Acc.csv"))
pd.DataFrame(data=np.array([ep, val_losses]).T, columns=["Epoch", "Loss"]).to_csv(Path(historypath2+"\\"+"Val_Loss.csv"))
print("CSVs saved in", historypath2)

def plot_acc(train_accuracies, val_accuracies):
    plt.plot(ep, train_accuracies)
    plt.plot(ep, val_accuracies)
    plt.title("model accuracy")
    plt.ylabel("accuracy")
    plt.xlabel("epoch")
    plt.xticks(np.arange(0, epochs+1, 10))
    plt.yticks(np.arange(0.0, 1.05, 0.05))
    plt.legend(["train", "validation"], loc="lower right")
    plt.show()

def plot_loss(train_losses, val_losses):
    plt.plot(ep, train_losses)
    plt.plot(ep, val_losses)
    plt.title("model loss")
    plt.ylabel("loss")
    plt.xlabel("epoch")
    plt.xticks(np.arange(0, epochs+1, 10))
    plt.ylim(bottom=-5, top=10)
    plt.legend(["train", "validation"], loc="upper right")
    plt.show()

plot_acc(train_accuracies, val_accuracies)
plot_loss(train_losses, val_losses)

print('Training Finished!!!')
# Out:
# Device: cuda:0 IMGSIZE:( 3 224 224 ) BatchSize: 64 Epochs: 120 Valsplit: 0.25 Class: ['Damage', 'NoDamage'] Final Layer Nodes: 2048
# TrainData Size: 1647 TrainData Batches 26 ValData Size: 549 ValData Batches: 9
# Epoch 1 TrainLoss: 0.6916 TrainAcc: 0.5240
# Epoch 1 ValLoss: 0.6924 ValAcc: 0.5209
#
# Epoch 2 TrainLoss: 0.6885 TrainAcc: 0.5543
# Epoch 2 ValLoss: 0.6892 ValAcc: 0.5446
#
# Epoch 3 TrainLoss: 0.6866 TrainAcc: 0.5798
# Epoch 3 ValLoss: 0.6873 ValAcc: 0.5483
#
# Epoch 4 TrainLoss: 0.6842 TrainAcc: 0.5999
# Epoch 4 ValLoss: 0.6855 ValAcc: 0.5920
#
# Epoch 5 TrainLoss: 0.6811 TrainAcc: 0.6078
# Epoch 5 ValLoss: 0.6837 ValAcc: 0.5701
#
# Epoch 6 TrainLoss: 0.6794 TrainAcc: 0.6315
# Epoch 6 ValLoss: 0.6861 ValAcc: 0.5883
#
# Epoch 7 TrainLoss: 0.6757 TrainAcc: 0.6357
# Epoch 7 ValLoss: 0.6786 ValAcc: 0.6357
#
# Epoch 8 TrainLoss: 0.6719 TrainAcc: 0.6533
# Epoch 8 ValLoss: 0.6753 ValAcc: 0.6138
#
# Epoch 9 TrainLoss: 0.6680 TrainAcc: 0.6570
# Epoch 9 ValLoss: 0.6702 ValAcc: 0.6393
#
# Epoch 10 TrainLoss: 0.6639 TrainAcc: 0.6727
# Epoch 10 ValLoss: 0.6673 ValAcc: 0.6175
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\Weights\10\model_weights20241024_1526.pth
#
# Epoch 11 TrainLoss: 0.6601 TrainAcc: 0.6788
# Epoch 11 ValLoss: 0.6703 ValAcc: 0.6466
#
# Epoch 12 TrainLoss: 0.6550 TrainAcc: 0.6818
# Epoch 12 ValLoss: 0.6652 ValAcc: 0.6339
#
# Epoch 13 TrainLoss: 0.6502 TrainAcc: 0.7061
# Epoch 13 ValLoss: 0.6590 ValAcc: 0.6503
#
# Epoch 14 TrainLoss: 0.6407 TrainAcc: 0.7256
# Epoch 14 ValLoss: 0.6607 ValAcc: 0.6248
#
# Epoch 15 TrainLoss: 0.6371 TrainAcc: 0.7335
# Epoch 15 ValLoss: 0.6513 ValAcc: 0.6594
#
# Epoch 16 TrainLoss: 0.6299 TrainAcc: 0.7322
# Epoch 16 ValLoss: 0.6531 ValAcc: 0.6667
#
# Epoch 17 TrainLoss: 0.6239 TrainAcc: 0.7383
# Epoch 17 ValLoss: 0.6379 ValAcc: 0.6940
#
# Epoch 18 TrainLoss: 0.6147 TrainAcc: 0.7590
# Epoch 18 ValLoss: 0.6692 ValAcc: 0.5847
#
# Epoch 19 TrainLoss: 0.6116 TrainAcc: 0.7413
# Epoch 19 ValLoss: 0.6475 ValAcc: 0.6521
#
# Epoch 20 TrainLoss: 0.5985 TrainAcc: 0.7711
# Epoch 20 ValLoss: 0.6465 ValAcc: 0.6448
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\Weights\20\model_weights20241024_1526.pth
#
# Epoch 21 TrainLoss: 0.5905 TrainAcc: 0.7620
# Epoch 21 ValLoss: 0.6252 ValAcc: 0.7140
#
# Epoch 22 TrainLoss: 0.5782 TrainAcc: 0.7863
# Epoch 22 ValLoss: 0.6248 ValAcc: 0.6703
#
# Epoch 23 TrainLoss: 0.5718 TrainAcc: 0.7875
# Epoch 23 ValLoss: 0.6130 ValAcc: 0.6794
#
# Epoch 24 TrainLoss: 0.5616 TrainAcc: 0.8021
# Epoch 24 ValLoss: 0.6119 ValAcc: 0.6958
#
# Epoch 25 TrainLoss: 0.5512 TrainAcc: 0.8094
# Epoch 25 ValLoss: 0.5960 ValAcc: 0.7140
#
# Epoch 26 TrainLoss: 0.5428 TrainAcc: 0.8203
# Epoch 26 ValLoss: 0.5957 ValAcc: 0.7231
#
# Epoch 27 TrainLoss: 0.5313 TrainAcc: 0.8227
# Epoch 27 ValLoss: 0.5849 ValAcc: 0.7650
#
# Epoch 28 TrainLoss: 0.5251 TrainAcc: 0.8276
# Epoch 28 ValLoss: 0.5674 ValAcc: 0.7377
#
# Epoch 29 TrainLoss: 0.5108 TrainAcc: 0.8506
# Epoch 29 ValLoss: 0.6191 ValAcc: 0.6612
#
# Epoch 30 TrainLoss: 0.5041 TrainAcc: 0.8537
# Epoch 30 ValLoss: 0.5794 ValAcc: 0.7341
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\Weights\30\model_weights20241024_1526.pth
#
# Epoch 31 TrainLoss: 0.4912 TrainAcc: 0.8676
# Epoch 31 ValLoss: 0.5857 ValAcc: 0.7213
#
# Epoch 32 TrainLoss: 0.4848 TrainAcc: 0.8676
# Epoch 32 ValLoss: 0.5560 ValAcc: 0.7486
#
# Epoch 33 TrainLoss: 0.4748 TrainAcc: 0.8822
# Epoch 33 ValLoss: 0.5370 ValAcc: 0.7869
#
# Epoch 34 TrainLoss: 0.4700 TrainAcc: 0.8816
# Epoch 34 ValLoss: 0.5689 ValAcc: 0.7377
#
# Epoch 35 TrainLoss: 0.4619 TrainAcc: 0.8883
# Epoch 35 ValLoss: 0.5775 ValAcc: 0.7140
#
# Epoch 36 TrainLoss: 0.4542 TrainAcc: 0.8962
# Epoch 36 ValLoss: 0.5343 ValAcc: 0.7596
#
# Epoch 37 TrainLoss: 0.4479 TrainAcc: 0.8968
# Epoch 37 ValLoss: 0.5644 ValAcc: 0.7158
#
# Epoch 38 TrainLoss: 0.4438 TrainAcc: 0.9065
# Epoch 38 ValLoss: 0.5467 ValAcc: 0.7541
#
# Epoch 39 TrainLoss: 0.4310 TrainAcc: 0.9199
# Epoch 39 ValLoss: 0.5308 ValAcc: 0.7687
#
# Epoch 40 TrainLoss: 0.4293 TrainAcc: 0.9199
# Epoch 40 ValLoss: 0.5062 ValAcc: 0.7996
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\Weights\40\model_weights20241024_1526.pth
#
# Epoch 41 TrainLoss: 0.4208 TrainAcc: 0.9326
# Epoch 41 ValLoss: 0.5016 ValAcc: 0.8124
#
# Epoch 42 TrainLoss: 0.4189 TrainAcc: 0.9375
# Epoch 42 ValLoss: 0.5321 ValAcc: 0.7723
#
# Epoch 43 TrainLoss: 0.4103 TrainAcc: 0.9356
# Epoch 43 ValLoss: 0.5047 ValAcc: 0.8033
#
# Epoch 44 TrainLoss: 0.4088 TrainAcc: 0.9326
# Epoch 44 ValLoss: 0.5128 ValAcc: 0.8051
#
# Epoch 45 TrainLoss: 0.4016 TrainAcc: 0.9405
# Epoch 45 ValLoss: 0.5347 ValAcc: 0.7760
#
# Epoch 46 TrainLoss: 0.3990 TrainAcc: 0.9417
# Epoch 46 ValLoss: 0.5200 ValAcc: 0.7705
#
# Epoch 47 TrainLoss: 0.3938 TrainAcc: 0.9496
# Epoch 47 ValLoss: 0.4621 ValAcc: 0.8761
#
# Epoch 48 TrainLoss: 0.3940 TrainAcc: 0.9417
# Epoch 48 ValLoss: 0.5483 ValAcc: 0.7341
#
# Epoch 49 TrainLoss: 0.3869 TrainAcc: 0.9581
# Epoch 49 ValLoss: 0.4981 ValAcc: 0.8160
#
# Epoch 50 TrainLoss: 0.3814 TrainAcc: 0.9605
# Epoch 50 ValLoss: 0.4608 ValAcc: 0.8725
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\Weights\50\model_weights20241024_1526.pth
#
# Epoch 51 TrainLoss: 0.3809 TrainAcc: 0.9545
# Epoch 51 ValLoss: 0.4923 ValAcc: 0.8160
#
# Epoch 52 TrainLoss: 0.3804 TrainAcc: 0.9545
# Epoch 52 ValLoss: 0.6000 ValAcc: 0.6612
#
# Epoch 53 TrainLoss: 0.3743 TrainAcc: 0.9642
# Epoch 53 ValLoss: 0.4622 ValAcc: 0.8415
#
# Epoch 54 TrainLoss: 0.3746 TrainAcc: 0.9599
# Epoch 54 ValLoss: 0.4669 ValAcc: 0.8452
#
# Epoch 55 TrainLoss: 0.3656 TrainAcc: 0.9678
# Epoch 55 ValLoss: 0.4772 ValAcc: 0.8288
#
# Epoch 56 TrainLoss: 0.3664 TrainAcc: 0.9630
# Epoch 56 ValLoss: 0.4342 ValAcc: 0.8944
#
# Epoch 57 TrainLoss: 0.3631 TrainAcc: 0.9672
# Epoch 57 ValLoss: 0.4716 ValAcc: 0.8361
#
# Epoch 58 TrainLoss: 0.3574 TrainAcc: 0.9733
# Epoch 58 ValLoss: 0.4648 ValAcc: 0.8652
#
# Epoch 59 TrainLoss: 0.3584 TrainAcc: 0.9739
# Epoch 59 ValLoss: 0.4546 ValAcc: 0.8506
#
# Epoch 60 TrainLoss: 0.3544 TrainAcc: 0.9781
# Epoch 60 ValLoss: 0.4180 ValAcc: 0.9016
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\Weights\60\model_weights20241024_1526.pth
#
# Epoch 61 TrainLoss: 0.3518 TrainAcc: 0.9769
# Epoch 61 ValLoss: 0.4326 ValAcc: 0.8689
#
# Epoch 62 TrainLoss: 0.3472 TrainAcc: 0.9836
# Epoch 62 ValLoss: 0.4424 ValAcc: 0.8689
#
# Epoch 63 TrainLoss: 0.3441 TrainAcc: 0.9854
# Epoch 63 ValLoss: 0.4726 ValAcc: 0.8415
#
# Epoch 64 TrainLoss: 0.3512 TrainAcc: 0.9769
# Epoch 64 ValLoss: 0.4408 ValAcc: 0.8852
#
# Epoch 65 TrainLoss: 0.3448 TrainAcc: 0.9824
# Epoch 65 ValLoss: 0.4663 ValAcc: 0.8397
#
# Epoch 66 TrainLoss: 0.3466 TrainAcc: 0.9781
# Epoch 66 ValLoss: 0.4078 ValAcc: 0.9162
#
# Epoch 67 TrainLoss: 0.3430 TrainAcc: 0.9830
# Epoch 67 ValLoss: 0.4241 ValAcc: 0.8944
#
# Epoch 68 TrainLoss: 0.3403 TrainAcc: 0.9848
# Epoch 68 ValLoss: 0.4417 ValAcc: 0.8798
#
# Epoch 69 TrainLoss: 0.3400 TrainAcc: 0.9872
# Epoch 69 ValLoss: 0.4444 ValAcc: 0.8707
#
# Epoch 70 TrainLoss: 0.3390 TrainAcc: 0.9866
# Epoch 70 ValLoss: 0.3985 ValAcc: 0.9199
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\Weights\70\model_weights20241024_1526.pth
#
# Epoch 71 TrainLoss: 0.3372 TrainAcc: 0.9866
# Epoch 71 ValLoss: 0.3972 ValAcc: 0.9344
#
# Epoch 72 TrainLoss: 0.3360 TrainAcc: 0.9854
# Epoch 72 ValLoss: 0.3919 ValAcc: 0.9308
#
# Epoch 73 TrainLoss: 0.3332 TrainAcc: 0.9903
# Epoch 73 ValLoss: 0.4265 ValAcc: 0.8871
#
# Epoch 74 TrainLoss: 0.3325 TrainAcc: 0.9921
# Epoch 74 ValLoss: 0.3859 ValAcc: 0.9308
#
# Epoch 75 TrainLoss: 0.3328 TrainAcc: 0.9897
# Epoch 75 ValLoss: 0.4036 ValAcc: 0.9235
#
# Epoch 76 TrainLoss: 0.3365 TrainAcc: 0.9854
# Epoch 76 ValLoss: 0.3971 ValAcc: 0.9107
#
# Epoch 77 TrainLoss: 0.3326 TrainAcc: 0.9879
# Epoch 77 ValLoss: 0.4337 ValAcc: 0.8616
#
# Epoch 78 TrainLoss: 0.3293 TrainAcc: 0.9897
# Epoch 78 ValLoss: 0.3940 ValAcc: 0.9126
#
# Epoch 79 TrainLoss: 0.3300 TrainAcc: 0.9921
# Epoch 79 ValLoss: 0.3674 ValAcc: 0.9563
#
# Epoch 80 TrainLoss: 0.3300 TrainAcc: 0.9915
# Epoch 80 ValLoss: 0.4083 ValAcc: 0.9162
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\Weights\80\model_weights20241024_1526.pth
#
# Epoch 81 TrainLoss: 0.3302 TrainAcc: 0.9903
# Epoch 81 ValLoss: 0.4422 ValAcc: 0.8597
#
# Epoch 82 TrainLoss: 0.3291 TrainAcc: 0.9927
# Epoch 82 ValLoss: 0.3835 ValAcc: 0.9381
#
# Epoch 83 TrainLoss: 0.3293 TrainAcc: 0.9903
# Epoch 83 ValLoss: 0.4197 ValAcc: 0.8889
#
# Epoch 84 TrainLoss: 0.3270 TrainAcc: 0.9927
# Epoch 84 ValLoss: 0.3933 ValAcc: 0.9290
#
# Epoch 85 TrainLoss: 0.3260 TrainAcc: 0.9933
# Epoch 85 ValLoss: 0.4574 ValAcc: 0.8488
#
# Epoch 86 TrainLoss: 0.3327 TrainAcc: 0.9860
# Epoch 86 ValLoss: 0.4049 ValAcc: 0.9126
#
# Epoch 87 TrainLoss: 0.3243 TrainAcc: 0.9945
# Epoch 87 ValLoss: 0.4039 ValAcc: 0.9071
#
# Epoch 88 TrainLoss: 0.3268 TrainAcc: 0.9915
# Epoch 88 ValLoss: 0.4053 ValAcc: 0.9071
#
# Epoch 89 TrainLoss: 0.3221 TrainAcc: 0.9964
# Epoch 89 ValLoss: 0.3480 ValAcc: 0.9763
#
# Epoch 90 TrainLoss: 0.3218 TrainAcc: 0.9976
# Epoch 90 ValLoss: 0.3557 ValAcc: 0.9690
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\Weights\90\model_weights20241024_1526.pth
#
# Epoch 91 TrainLoss: 0.3240 TrainAcc: 0.9933
# Epoch 91 ValLoss: 0.3716 ValAcc: 0.9472
#
# Epoch 92 TrainLoss: 0.3244 TrainAcc: 0.9945
# Epoch 92 ValLoss: 0.3665 ValAcc: 0.9526
#
# Epoch 93 TrainLoss: 0.3238 TrainAcc: 0.9945
# Epoch 93 ValLoss: 0.4550 ValAcc: 0.8561
#
# Epoch 94 TrainLoss: 0.3265 TrainAcc: 0.9927
# Epoch 94 ValLoss: 0.4238 ValAcc: 0.8871
#
# Epoch 95 TrainLoss: 0.3245 TrainAcc: 0.9939
# Epoch 95 ValLoss: 0.3922 ValAcc: 0.9217
#
# Epoch 96 TrainLoss: 0.3242 TrainAcc: 0.9927
# Epoch 96 ValLoss: 0.3707 ValAcc: 0.9599
#
# Epoch 97 TrainLoss: 0.3213 TrainAcc: 0.9970
# Epoch 97 ValLoss: 0.3479 ValAcc: 0.9709
#
# Epoch 98 TrainLoss: 0.3203 TrainAcc: 0.9970
# Epoch 98 ValLoss: 0.4332 ValAcc: 0.8743
#
# Epoch 99 TrainLoss: 0.3215 TrainAcc: 0.9964
# Epoch 99 ValLoss: 0.3770 ValAcc: 0.9417
#
# Epoch 100 TrainLoss: 0.3216 TrainAcc: 0.9970
# Epoch 100 ValLoss: 0.3553 ValAcc: 0.9672
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\Weights\100\model_weights20241024_1526.pth
#
# Epoch 101 TrainLoss: 0.3205 TrainAcc: 0.9951
# Epoch 101 ValLoss: 0.3643 ValAcc: 0.9526
#
# Epoch 102 TrainLoss: 0.3202 TrainAcc: 0.9964
# Epoch 102 ValLoss: 0.3545 ValAcc: 0.9672
#
# Epoch 103 TrainLoss: 0.3201 TrainAcc: 0.9970
# Epoch 103 ValLoss: 0.3787 ValAcc: 0.9472
#
# Epoch 104 TrainLoss: 0.3202 TrainAcc: 0.9970
# Epoch 104 ValLoss: 0.3590 ValAcc: 0.9636
#
# Epoch 105 TrainLoss: 0.3203 TrainAcc: 0.9970
# Epoch 105 ValLoss: 0.3822 ValAcc: 0.9381
#
# Epoch 106 TrainLoss: 0.3189 TrainAcc: 0.9970
# Epoch 106 ValLoss: 0.3988 ValAcc: 0.9162
#
# Epoch 107 TrainLoss: 0.3188 TrainAcc: 0.9988
# Epoch 107 ValLoss: 0.3975 ValAcc: 0.9089
#
# Epoch 108 TrainLoss: 0.3220 TrainAcc: 0.9970
# Epoch 108 ValLoss: 0.4043 ValAcc: 0.9071
#
# Epoch 109 TrainLoss: 0.3195 TrainAcc: 0.9988
# Epoch 109 ValLoss: 0.3755 ValAcc: 0.9399
#
# Epoch 110 TrainLoss: 0.3174 TrainAcc: 0.9994
# Epoch 110 ValLoss: 0.3362 ValAcc: 0.9818
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\Weights\110\model_weights20241024_1526.pth
#
# Epoch 111 TrainLoss: 0.3174 TrainAcc: 0.9982
# Epoch 111 ValLoss: 0.3459 ValAcc: 0.9690
#
# Epoch 112 TrainLoss: 0.3172 TrainAcc: 0.9988
# Epoch 112 ValLoss: 0.3529 ValAcc: 0.9690
#
# Epoch 113 TrainLoss: 0.3185 TrainAcc: 0.9994
# Epoch 113 ValLoss: 0.3514 ValAcc: 0.9672
#
# Epoch 114 TrainLoss: 0.3188 TrainAcc: 0.9988
# Epoch 114 ValLoss: 0.3891 ValAcc: 0.9235
#
# Epoch 115 TrainLoss: 0.3192 TrainAcc: 0.9964
# Epoch 115 ValLoss: 0.3505 ValAcc: 0.9690
#
# Epoch 116 TrainLoss: 0.3186 TrainAcc: 0.9994
# Epoch 116 ValLoss: 0.3486 ValAcc: 0.9727
#
# Epoch 117 TrainLoss: 0.3192 TrainAcc: 0.9976
# Epoch 117 ValLoss: 0.3413 ValAcc: 0.9763
#
# Epoch 118 TrainLoss: 0.3174 TrainAcc: 1.0000
# Epoch 118 ValLoss: 0.3535 ValAcc: 0.9636
#
# Epoch 119 TrainLoss: 0.3187 TrainAcc: 0.9994
# Epoch 119 ValLoss: 0.3467 ValAcc: 0.9745
#
# Epoch 120 TrainLoss: 0.3187 TrainAcc: 0.9976
# Epoch 120 ValLoss: 0.3503 ValAcc: 0.9727
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\Weights\120\model_weights20241024_1526.pth
#
# CSVs saved in C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\History\20241024_1526
# Training Finished!!!
