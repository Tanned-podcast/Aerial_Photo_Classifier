# %%
import datetime
dt_now = datetime.datetime.now()
print(dt_now.strftime('%Y%m%d_%H%M'))
# Out:
# 20231219_1038

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import torch
import numpy as np
print(np.array(torch.tensor([1])))
# Out:
# [1]

# %%
#PyTorchはモデルの最終レイヤに損失関数とsoftmaxが入っていない loss_fnに入っているのでカスタム可能
import torch
from torchinfo import summary
import torchvision.models as models
import torch.nn as nn

resnet50 = models.resnet50(weights='DEFAULT')


resnet50.conv1 = torch.nn.Conv2d(3,64,kernel_size = (7,7),stride = (2,2), padding = (3,3), bias = False)
num_ftrs = resnet50.fc.in_features
#modifying final layer
resnet50.fc = nn.Linear(num_ftrs,2)
summary(model=resnet50, input_size=(8, 3, 16, 16))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ResNet                                   [8, 2]                    --
# ├─Conv2d: 1-1                            [8, 64, 8, 8]             9,408
# ├─BatchNorm2d: 1-2                       [8, 64, 8, 8]             128
# ├─ReLU: 1-3                              [8, 64, 8, 8]             --
# ├─MaxPool2d: 1-4                         [8, 64, 4, 4]             --
# ├─Sequential: 1-5                        [8, 256, 4, 4]            --
# │    └─Bottleneck: 2-1                   [8, 256, 4, 4]            --
# │    │    └─Conv2d: 3-1                  [8, 64, 4, 4]             4,096
# │    │    └─BatchNorm2d: 3-2             [8, 64, 4, 4]             128
# │    │    └─ReLU: 3-3                    [8, 64, 4, 4]             --
# │    │    └─Conv2d: 3-4                  [8, 64, 4, 4]             36,864
# │    │    └─BatchNorm2d: 3-5             [8, 64, 4, 4]             128
# │    │    └─ReLU: 3-6                    [8, 64, 4, 4]             --
# │    │    └─Conv2d: 3-7                  [8, 256, 4, 4]            16,384
# │    │    └─BatchNorm2d: 3-8             [8, 256, 4, 4]            512
# │    │    └─Sequential: 3-9              [8, 256, 4, 4]            16,896
# │    │    └─ReLU: 3-10                   [8, 256, 4, 4]            --
# │    └─Bottleneck: 2-2                   [8, 256, 4, 4]            --
# │    │    └─Conv2d: 3-11                 [8, 64, 4, 4]             16,384
# │    │    └─BatchNorm2d: 3-12            [8, 64, 4, 4]             128
# │    │    └─ReLU: 3-13                   [8, 64, 4, 4]             --
# │    │    └─Conv2d: 3-14                 [8, 64, 4, 4]             36,864
# │    │    └─BatchNorm2d: 3-15            [8, 64, 4, 4]             128
# │    │    └─ReLU: 3-16                   [8, 64, 4, 4]             --
# │    │    └─Conv2d: 3-17                 [8, 256, 4, 4]            16,384
# │    │    └─BatchNorm2d: 3-18            [8, 256, 4, 4]            512
# │    │    └─ReLU: 3-19                   [8, 256, 4, 4]            --
# │    └─Bottleneck: 2-3                   [8, 256, 4, 4]            --
# │    │    └─Conv2d: 3-20                 [8, 64, 4, 4]             16,384
# │    │    └─BatchNorm2d: 3-21            [8, 64, 4, 4]             128
# │    │    └─ReLU: 3-22                   [8, 64, 4, 4]             --
# │    │    └─Conv2d: 3-23                 [8, 64, 4, 4]             36,864
# │    │    └─BatchNorm2d: 3-24            [8, 64, 4, 4]             128
# │    │    └─ReLU: 3-25                   [8, 64, 4, 4]             --
# │    │    └─Conv2d: 3-26                 [8, 256, 4, 4]            16,384
# │    │    └─BatchNorm2d: 3-27            [8, 256, 4, 4]            512
# │    │    └─ReLU: 3-28                   [8, 256, 4, 4]            --
# ├─Sequential: 1-6                        [8, 512, 2, 2]            --
# │    └─Bottleneck: 2-4                   [8, 512, 2, 2]            --
# │    │    └─Conv2d: 3-29                 [8, 128, 4, 4]            32,768
# │    │    └─BatchNorm2d: 3-30            [8, 128, 4, 4]            256
# │    │    └─ReLU: 3-31                   [8, 128, 4, 4]            --
# │    │    └─Conv2d: 3-32                 [8, 128, 2, 2]            147,456
# │    │    └─BatchNorm2d: 3-33            [8, 128, 2, 2]            256
# │    │    └─ReLU: 3-34                   [8, 128, 2, 2]            --
# │    │    └─Conv2d: 3-35                 [8, 512, 2, 2]            65,536
# │    │    └─BatchNorm2d: 3-36            [8, 512, 2, 2]            1,024
# │    │    └─Sequential: 3-37             [8, 512, 2, 2]            132,096
# │    │    └─ReLU: 3-38                   [8, 512, 2, 2]            --
# │    └─Bottleneck: 2-5                   [8, 512, 2, 2]            --
# │    │    └─Conv2d: 3-39                 [8, 128, 2, 2]            65,536
# │    │    └─BatchNorm2d: 3-40            [8, 128, 2, 2]            256
# │    │    └─ReLU: 3-41                   [8, 128, 2, 2]            --
# │    │    └─Conv2d: 3-42                 [8, 128, 2, 2]            147,456
# │    │    └─BatchNorm2d: 3-43            [8, 128, 2, 2]            256
# │    │    └─ReLU: 3-44                   [8, 128, 2, 2]            --
# │    │    └─Conv2d: 3-45                 [8, 512, 2, 2]            65,536
# │    │    └─BatchNorm2d: 3-46            [8, 512, 2, 2]            1,024
# │    │    └─ReLU: 3-47                   [8, 512, 2, 2]            --
# │    └─Bottleneck: 2-6                   [8, 512, 2, 2]            --
# │    │    └─Conv2d: 3-48                 [8, 128, 2, 2]            65,536
# │    │    └─BatchNorm2d: 3-49            [8, 128, 2, 2]            256
# │    │    └─ReLU: 3-50                   [8, 128, 2, 2]            --
# │    │    └─Conv2d: 3-51                 [8, 128, 2, 2]            147,456
# │    │    └─BatchNorm2d: 3-52            [8, 128, 2, 2]            256
# │    │    └─ReLU: 3-53                   [8, 128, 2, 2]            --
# │    │    └─Conv2d: 3-54                 [8, 512, 2, 2]            65,536
# │    │    └─BatchNorm2d: 3-55            [8, 512, 2, 2]            1,024
# │    │    └─ReLU: 3-56                   [8, 512, 2, 2]            --
# │    └─Bottleneck: 2-7                   [8, 512, 2, 2]            --
# │    │    └─Conv2d: 3-57                 [8, 128, 2, 2]            65,536
# │    │    └─BatchNorm2d: 3-58            [8, 128, 2, 2]            256
# │    │    └─ReLU: 3-59                   [8, 128, 2, 2]            --
# │    │    └─Conv2d: 3-60                 [8, 128, 2, 2]            147,456
# │    │    └─BatchNorm2d: 3-61            [8, 128, 2, 2]            256
# │    │    └─ReLU: 3-62                   [8, 128, 2, 2]            --
# │    │    └─Conv2d: 3-63                 [8, 512, 2, 2]            65,536
# │    │    └─BatchNorm2d: 3-64            [8, 512, 2, 2]            1,024
# │    │    └─ReLU: 3-65                   [8, 512, 2, 2]            --
# ├─Sequential: 1-7                        [8, 1024, 1, 1]           --
# │    └─Bottleneck: 2-8                   [8, 1024, 1, 1]           --
# │    │    └─Conv2d: 3-66                 [8, 256, 2, 2]            131,072
# │    │    └─BatchNorm2d: 3-67            [8, 256, 2, 2]            512
# │    │    └─ReLU: 3-68                   [8, 256, 2, 2]            --
# │    │    └─Conv2d: 3-69                 [8, 256, 1, 1]            589,824
# │    │    └─BatchNorm2d: 3-70            [8, 256, 1, 1]            512
# │    │    └─ReLU: 3-71                   [8, 256, 1, 1]            --
# │    │    └─Conv2d: 3-72                 [8, 1024, 1, 1]           262,144
# │    │    └─BatchNorm2d: 3-73            [8, 1024, 1, 1]           2,048
# │    │    └─Sequential: 3-74             [8, 1024, 1, 1]           526,336
# │    │    └─ReLU: 3-75                   [8, 1024, 1, 1]           --
# │    └─Bottleneck: 2-9                   [8, 1024, 1, 1]           --
# │    │    └─Conv2d: 3-76                 [8, 256, 1, 1]            262,144
# │    │    └─BatchNorm2d: 3-77            [8, 256, 1, 1]            512
# │    │    └─ReLU: 3-78                   [8, 256, 1, 1]            --
# │    │    └─Conv2d: 3-79                 [8, 256, 1, 1]            589,824
# │    │    └─BatchNorm2d: 3-80            [8, 256, 1, 1]            512
# │    │    └─ReLU: 3-81                   [8, 256, 1, 1]            --
# │    │    └─Conv2d: 3-82                 [8, 1024, 1, 1]           262,144
# │    │    └─BatchNorm2d: 3-83            [8, 1024, 1, 1]           2,048
# │    │    └─ReLU: 3-84                   [8, 1024, 1, 1]           --
# │    └─Bottleneck: 2-10                  [8, 1024, 1, 1]           --
# │    │    └─Conv2d: 3-85                 [8, 256, 1, 1]            262,144
# │    │    └─BatchNorm2d: 3-86            [8, 256, 1, 1]            512
# │    │    └─ReLU: 3-87                   [8, 256, 1, 1]            --
# │    │    └─Conv2d: 3-88                 [8, 256, 1, 1]            589,824
# │    │    └─BatchNorm2d: 3-89            [8, 256, 1, 1]            512
# │    │    └─ReLU: 3-90                   [8, 256, 1, 1]            --
# │    │    └─Conv2d: 3-91                 [8, 1024, 1, 1]           262,144
# │    │    └─BatchNorm2d: 3-92            [8, 1024, 1, 1]           2,048
# │    │    └─ReLU: 3-93                   [8, 1024, 1, 1]           --
# │    └─Bottleneck: 2-11                  [8, 1024, 1, 1]           --
# │    │    └─Conv2d: 3-94                 [8, 256, 1, 1]            262,144
# │    │    └─BatchNorm2d: 3-95            [8, 256, 1, 1]            512
# │    │    └─ReLU: 3-96                   [8, 256, 1, 1]            --
# │    │    └─Conv2d: 3-97                 [8, 256, 1, 1]            589,824
# │    │    └─BatchNorm2d: 3-98            [8, 256, 1, 1]            512
# │    │    └─ReLU: 3-99                   [8, 256, 1, 1]            --
# │    │    └─Conv2d: 3-100                [8, 1024, 1, 1]           262,144
# │    │    └─BatchNorm2d: 3-101           [8, 1024, 1, 1]           2,048
# │    │    └─ReLU: 3-102                  [8, 1024, 1, 1]           --
# │    └─Bottleneck: 2-12                  [8, 1024, 1, 1]           --
# │    │    └─Conv2d: 3-103                [8, 256, 1, 1]            262,144
# │    │    └─BatchNorm2d: 3-104           [8, 256, 1, 1]            512
# │    │    └─ReLU: 3-105                  [8, 256, 1, 1]            --
# │    │    └─Conv2d: 3-106                [8, 256, 1, 1]            589,824
# │    │    └─BatchNorm2d: 3-107           [8, 256, 1, 1]            512
# │    │    └─ReLU: 3-108                  [8, 256, 1, 1]            --
# │    │    └─Conv2d: 3-109                [8, 1024, 1, 1]           262,144
# │    │    └─BatchNorm2d: 3-110           [8, 1024, 1, 1]           2,048
# │    │    └─ReLU: 3-111                  [8, 1024, 1, 1]           --
# │    └─Bottleneck: 2-13                  [8, 1024, 1, 1]           --
# │    │    └─Conv2d: 3-112                [8, 256, 1, 1]            262,144
# │    │    └─BatchNorm2d: 3-113           [8, 256, 1, 1]            512
# │    │    └─ReLU: 3-114                  [8, 256, 1, 1]            --
# │    │    └─Conv2d: 3-115                [8, 256, 1, 1]            589,824
# │    │    └─BatchNorm2d: 3-116           [8, 256, 1, 1]            512
# │    │    └─ReLU: 3-117                  [8, 256, 1, 1]            --
# │    │    └─Conv2d: 3-118                [8, 1024, 1, 1]           262,144
# │    │    └─BatchNorm2d: 3-119           [8, 1024, 1, 1]           2,048
# │    │    └─ReLU: 3-120                  [8, 1024, 1, 1]           --
# ├─Sequential: 1-8                        [8, 2048, 1, 1]           --
# │    └─Bottleneck: 2-14                  [8, 2048, 1, 1]           --
# │    │    └─Conv2d: 3-121                [8, 512, 1, 1]            524,288
# │    │    └─BatchNorm2d: 3-122           [8, 512, 1, 1]            1,024
# │    │    └─ReLU: 3-123                  [8, 512, 1, 1]            --
# │    │    └─Conv2d: 3-124                [8, 512, 1, 1]            2,359,296
# │    │    └─BatchNorm2d: 3-125           [8, 512, 1, 1]            1,024
# │    │    └─ReLU: 3-126                  [8, 512, 1, 1]            --
# │    │    └─Conv2d: 3-127                [8, 2048, 1, 1]           1,048,576
# │    │    └─BatchNorm2d: 3-128           [8, 2048, 1, 1]           4,096
# │    │    └─Sequential: 3-129            [8, 2048, 1, 1]           2,101,248
# │    │    └─ReLU: 3-130                  [8, 2048, 1, 1]           --
# │    └─Bottleneck: 2-15                  [8, 2048, 1, 1]           --
# │    │    └─Conv2d: 3-131                [8, 512, 1, 1]            1,048,576
# │    │    └─BatchNorm2d: 3-132           [8, 512, 1, 1]            1,024
# │    │    └─ReLU: 3-133                  [8, 512, 1, 1]            --
# │    │    └─Conv2d: 3-134                [8, 512, 1, 1]            2,359,296
# │    │    └─BatchNorm2d: 3-135           [8, 512, 1, 1]            1,024
# │    │    └─ReLU: 3-136                  [8, 512, 1, 1]            --
# │    │    └─Conv2d: 3-137                [8, 2048, 1, 1]           1,048,576
# │    │    └─BatchNorm2d: 3-138           [8, 2048, 1, 1]           4,096
# │    │    └─ReLU: 3-139                  [8, 2048, 1, 1]           --
# │    └─Bottleneck: 2-16                  [8, 2048, 1, 1]           --
# │    │    └─Conv2d: 3-140                [8, 512, 1, 1]            1,048,576
# │    │    └─BatchNorm2d: 3-141           [8, 512, 1, 1]            1,024
# │    │    └─ReLU: 3-142                  [8, 512, 1, 1]            --
# │    │    └─Conv2d: 3-143                [8, 512, 1, 1]            2,359,296
# │    │    └─BatchNorm2d: 3-144           [8, 512, 1, 1]            1,024
# │    │    └─ReLU: 3-145                  [8, 512, 1, 1]            --
# │    │    └─Conv2d: 3-146                [8, 2048, 1, 1]           1,048,576
# │    │    └─BatchNorm2d: 3-147           [8, 2048, 1, 1]           4,096
# │    │    └─ReLU: 3-148                  [8, 2048, 1, 1]           --
# ├─AdaptiveAvgPool2d: 1-9                 [8, 2048, 1, 1]           --
# ├─Linear: 1-10                           [8, 2]                    4,098
# ==========================================================================================
# Total params: 23,512,130
# Trainable params: 23,512,130
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 253.79
# ==========================================================================================
# Input size (MB): 0.02
# Forward/backward pass size (MB): 8.29
# Params size (MB): 94.05
# Estimated Total Size (MB): 102.36
# ==========================================================================================

# %%
import torch
import torch.nn as nn

# モデルの出力（予測された確率）
output = torch.randn(1, requires_grad=True)  # 例えば、モデルの出力をランダムに生成

# 正解ラベル（0または1）
target = torch.tensor([1.0])  # 例えば、1のラベル

# BCE損失を計算
loss_fn = nn.BCELoss()
loss = loss_fn(torch.sigmoid(output), target)

print("BCE Loss:", loss.item())
# Out:
# BCE Loss: 0.6826429963111877

# %%
import glob
import os
import numpy as np
import torch
import torch.optim as optim
import torchvision.transforms.functional as TF
from torchvision.transforms import v2
import torchvision.models as models
import torch.nn as nn
import cv2
from torch.utils.data import Dataset
from pathlib import Path
from typing import List, Tuple
from torch.utils.data import DataLoader
from torch.utils.data import random_split
import matplotlib.pyplot as plt
import datetime
import pandas as pd
import seaborn as sns; sns.set() # sns.set() ==> グラフの見た目をseabornに合わせる
# %matplotlib inline

time = datetime.datetime.now()
filedate=time.strftime('%Y%m%d_%H%M')

device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('cpu')

Channels=3
batch_size=8
epochs=120
IMG_SIZE=224
valsplit=0.25

Classes = ["Damage", "NoDamage"]
ClassNum = len(Classes)

trainpath=r"C:\Users\kyohe\Aerial-Photo-Classifier\0522Data\Train"
savepath=r"C:\Users\kyohe\Aerial-Photo-Classifier\0522Data\Weights"
historypath=r"C:\Users\kyohe\Aerial-Photo-Classifier\0522Data\History"

'''
PytorchではDataloaderという,膨大なデータセットからでもメモリを圧迫せずに取り出せてforループにも対応するための枠組みがある
データセットをDataloaderが引っ張ってこれるような形式にするためにMyDataset(torch.utils.data.Dataset)というクラスを作れば，
あとはそのメソッドをtorch.utils.data.Datasetが勝手に使用してデータを加工してくれる
__init__, __getitem__, __len__をクラス内で必ず定義しなければならない
Dataloader内のデータはバッチごとにまとめられる
'''
class MyDataset(Dataset):
    def __init__(self, root: str, transforms, Classes) -> None:
        super().__init__()
        self.transforms = transforms
        self.Classes = Classes
        #globは複数のファイルのパスをまとめて取得する
        #訓練と訓練白黒の二個下のディレクトリから画像を取得
        self.data = list(sorted(Path(root).glob("*\*")))


    # ここで取り出すデータを指定している
    def __getitem__(self, index: int) -> Tuple[torch.Tensor, torch.Tensor]:
        data = self.data[index]

        img1 = cv2.imread(str(data))
        img1 = cv2.resize(img1, (IMG_SIZE, IMG_SIZE))
        img1 = TF.to_tensor(img1)

        # データの変形 (transforms)
        transformed_img = self.transforms(img1)

        #ラベル貼り：dataというパスを/で区切ってリストにし，クラス名のところをラベルに格納
        #クラス名は文字列なので，self.Classesの要素と比較して一致するところの番号をラベルとする
        label = str(data).split("\\")[-2]
        label = torch.tensor(self.Classes.index(label))

        return transformed_img, label

    # この method がないと DataLoader を呼び出す際にエラーを吐かれる
    def __len__(self) -> int:
        return len(self.data)


#入力データに施す処理
transforms = v2.Compose([
        #v2.RandomHorizontalFlip(p=0.5),
        v2.ToDtype(torch.float32, scale=True),
        v2.Normalize(mean=[0,0,0], std=[0.2, 0.2, 0.2]),
])


trainvalset = MyDataset(root=trainpath, transforms=transforms, Classes=Classes)
trainset, valset = random_split(trainvalset, [1-valsplit, valsplit])

trainloader = DataLoader(dataset=trainset,batch_size=batch_size,shuffle=True)
valloader = DataLoader(dataset=valset,batch_size=batch_size,shuffle=True)


resnet50 = models.resnet50(weights='DEFAULT')


resnet50.conv1 = torch.nn.Conv2d(Channels,64,kernel_size = (7,7),stride = (2,2), padding = (3,3), bias = False)
num_ftrs = resnet50.fc.in_features
#modifying final layer
resnet50.fc = nn.Linear(num_ftrs,ClassNum)

#GPUにニューラルネットワークを渡す
resnet50=resnet50.to(device)

#lossfunction&optimizer
#二値なのでBinaryCrossEntropy
loss_fn = nn.BCELoss()
optimizer = optim.SGD(resnet50.parameters(), lr=0.001, momentum=0.9)

print("Device:", device, "IMGSIZE:(", Channels, IMG_SIZE, IMG_SIZE, ")",  "BatchSize:", batch_size, "Epochs:", epochs, "Valsplit:", valsplit, "Class:", Classes, "Final Layer Nodes:", num_ftrs)

'''
trainiterator
enumerateはtrainloader内のすべてのdataに対してループし，繰り返し回数をbatchに渡すという意味
Dataloader内ではバッチごとにデータがまとめられるので1回の取り出しで1バッチ分のデータを丸々取り出せる
'''
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

def train(trainloader, valloader, model, loss_fn, optimizer, epochs):
    size = len(trainloader.dataset)
    num_batches = len(trainloader)
    size_val = len(valloader.dataset)
    num_batches_val = len(valloader)
    print("TrainData Size:", size, "TrainData Batches", num_batches, "ValData Size:", size_val, "ValData Batches:", num_batches_val)
    for epoch in range(epochs):
        running_loss, running_correct = 0, 0
        val_loss, val_correct = 0, 0
        for batch, (X, y) in enumerate(trainloader):
            X=X.to(device)
            y=y.to(device)
            # Compute prediction and loss
            pred = model(X)
            loss = loss_fn(torch.sigmoid(pred), y)

            # Backpropagation
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

            #損失と正解数の合計を計算しておき，後でそのエポック内での平均をとる
            running_loss += loss.item()
            running_correct += (pred.argmax(1) == y).type(torch.float).sum().item()

        epoch_loss = running_loss / num_batches
        epoch_acc = running_correct / size

        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_acc)

        print(f'Epoch {epoch + 1} TrainLoss: {epoch_loss:.4f} TrainAcc: {epoch_acc:.4f}')

        # Set the model to evaluation mode - important for batch normalization and dropout layers
        model.eval()
        # Evaluating the model with torch.no_grad() ensures that no gradients are computed during test mode
        # also serves to reduce unnecessary gradient computations and memory usage for tensors with requires_grad=True
        with torch.no_grad():
            for X, y in valloader:
                X=X.to(device)
                y=y.to(device)
                pred = model(X)
                val_loss += loss_fn(torch.sigmoid(pred), y).item()
                val_correct += (pred.argmax(1) == y).type(torch.float).sum().item()

            val_loss /= num_batches_val
            val_correct /= size_val
        # Set the model to train mode
        model.train()

        val_losses.append(val_loss)
        val_accuracies.append(val_correct)

        print(f'Epoch {epoch + 1} ValLoss: {val_loss:.4f} ValAcc: {val_correct:.4f}')

        #10epoch毎にパラメータを別々のフォルダに保存
        e1=epoch+1
        if (e1 % 10 == 0):
            savepath2 = Path(savepath+"\\"+str(e1)+"\model_weights"+filedate+".pth")
            print('Saving Model...')
            torch.save(model.state_dict(), savepath2)
            print('Model saved in', savepath2)

        print(' ')

train(trainloader, valloader, resnet50, loss_fn, optimizer, epochs)

#グラフ可視化
#pltの(x,y)のxにあたるepochのリスト　1から開始
ep=np.arange(1, epochs+1)

#グラフにプロットする正解率と損失のリストをCSVに書き出し to_csvは新規フォルダを作ってくれないのでosで作る
historypath2 = str(Path(historypath+"\\"+filedate))
os.mkdir(historypath2)
pd.DataFrame(data=np.array([ep, train_accuracies]).T, columns=["Epoch", "Accuracy"]).to_csv(Path(historypath2+"\\"+"Train_Acc.csv"))
pd.DataFrame(data=np.array([ep, train_losses]).T, columns=["Epoch", "Loss"]).to_csv(Path(historypath2+"\\"+"Train_Loss.csv"))
pd.DataFrame(data=np.array([ep, val_accuracies]).T, columns=["Epoch", "Accuracy"]).to_csv(Path(historypath2+"\\"+"Val_Acc.csv"))
pd.DataFrame(data=np.array([ep, val_losses]).T, columns=["Epoch", "Loss"]).to_csv(Path(historypath2+"\\"+"Val_Loss.csv"))
print("CSVs saved in", historypath2)

def plot_acc(train_accuracies, val_accuracies):
    plt.plot(ep, train_accuracies)
    plt.plot(ep, val_accuracies)
    plt.title("model accuracy")
    plt.ylabel("accuracy")
    plt.xlabel("epoch")
    plt.xticks(np.arange(0, epochs+1, 10))
    plt.yticks(np.arange(0.0, 1.05, 0.05))
    plt.legend(["train", "validation"], loc="lower right")
    plt.show()

def plot_loss(train_losses, val_losses):
    plt.plot(ep, train_losses)
    plt.plot(ep, val_losses)
    plt.title("model loss")
    plt.ylabel("loss")
    plt.xlabel("epoch")
    plt.xticks(np.arange(0, epochs+1, 10))
    plt.ylim(bottom=-5, top=10)
    plt.legend(["train", "validation"], loc="upper right")
    plt.show()

plot_acc(train_accuracies, val_accuracies)
plot_loss(train_losses, val_losses)

print('Training Finished!!!')
# Out:
# Device: cuda:0 IMGSIZE:( 3 224 224 ) BatchSize: 8 Epochs: 120 Valsplit: 0.25 Class: ['Damage', 'NoDamage'] Final Layer Nodes: 2048
# TrainData Size: 164 TrainData Batches 21 ValData Size: 54 ValData Batches: 7
# Epoch 1 TrainLoss: 0.6977 TrainAcc: 0.4817
# Epoch 1 ValLoss: 0.6857 ValAcc: 0.6296
#
# Epoch 2 TrainLoss: 0.6801 TrainAcc: 0.5488
# Epoch 2 ValLoss: 0.6899 ValAcc: 0.5370
#
# Epoch 3 TrainLoss: 0.6775 TrainAcc: 0.6280
# Epoch 3 ValLoss: 0.6876 ValAcc: 0.5556
#
# Epoch 4 TrainLoss: 0.6536 TrainAcc: 0.6098
# Epoch 4 ValLoss: 0.6698 ValAcc: 0.5926
#
# Epoch 5 TrainLoss: 0.6150 TrainAcc: 0.6280
# Epoch 5 ValLoss: 0.6770 ValAcc: 0.5556
#
# Epoch 6 TrainLoss: 0.5777 TrainAcc: 0.7378
# Epoch 6 ValLoss: 0.6422 ValAcc: 0.7407
#
# Epoch 7 TrainLoss: 0.5537 TrainAcc: 0.7439
# Epoch 7 ValLoss: 0.6730 ValAcc: 0.5741
#
# Epoch 8 TrainLoss: 0.5046 TrainAcc: 0.8171
# Epoch 8 ValLoss: 0.6529 ValAcc: 0.6111
#
# Epoch 9 TrainLoss: 0.4460 TrainAcc: 0.8110
# Epoch 9 ValLoss: 0.6385 ValAcc: 0.6852
#
# Epoch 10 TrainLoss: 0.3724 TrainAcc: 0.8720
# Epoch 10 ValLoss: 0.5410 ValAcc: 0.7593
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\0517Data\Weights\10\model_weights20240517_1334.pth
#
# Epoch 11 TrainLoss: 0.3218 TrainAcc: 0.9085
# Epoch 11 ValLoss: 0.5619 ValAcc: 0.7593
#
# Epoch 12 TrainLoss: 0.3483 TrainAcc: 0.8963
# Epoch 12 ValLoss: 0.5286 ValAcc: 0.8333
#
# Epoch 13 TrainLoss: 0.2855 TrainAcc: 0.9024
# Epoch 13 ValLoss: 0.4072 ValAcc: 0.8704
#
# Epoch 14 TrainLoss: 0.2065 TrainAcc: 0.9390
# Epoch 14 ValLoss: 0.5729 ValAcc: 0.6852
#
# Epoch 15 TrainLoss: 0.1829 TrainAcc: 0.9390
# Epoch 15 ValLoss: 0.5394 ValAcc: 0.7593
#
# Epoch 16 TrainLoss: 0.1441 TrainAcc: 0.9634
# Epoch 16 ValLoss: 0.4816 ValAcc: 0.7407
#
# Epoch 17 TrainLoss: 0.1349 TrainAcc: 0.9512
# Epoch 17 ValLoss: 0.2728 ValAcc: 0.8889
#
# Epoch 18 TrainLoss: 0.1043 TrainAcc: 0.9756
# Epoch 18 ValLoss: 0.3771 ValAcc: 0.8519
#
# Epoch 19 TrainLoss: 0.0715 TrainAcc: 0.9939
# Epoch 19 ValLoss: 0.3674 ValAcc: 0.8704
#
# Epoch 20 TrainLoss: 0.1477 TrainAcc: 0.9573
# Epoch 20 ValLoss: 0.6603 ValAcc: 0.7222
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\0517Data\Weights\20\model_weights20240517_1334.pth
#
# Epoch 21 TrainLoss: 0.0979 TrainAcc: 0.9695
# Epoch 21 ValLoss: 0.4294 ValAcc: 0.7593
#
# Epoch 22 TrainLoss: 0.0480 TrainAcc: 1.0000
# Epoch 22 ValLoss: 0.3313 ValAcc: 0.8333
#
# Epoch 23 TrainLoss: 0.0665 TrainAcc: 0.9817
# Epoch 23 ValLoss: 0.2342 ValAcc: 0.9444
#
# Epoch 24 TrainLoss: 0.1413 TrainAcc: 0.9695
# Epoch 24 ValLoss: 0.4048 ValAcc: 0.8519
#
# Epoch 25 TrainLoss: 0.0830 TrainAcc: 0.9756
# Epoch 25 ValLoss: 0.3512 ValAcc: 0.8889
#
# Epoch 26 TrainLoss: 0.0378 TrainAcc: 0.9939
# Epoch 26 ValLoss: 0.3250 ValAcc: 0.8148
#
# Epoch 27 TrainLoss: 0.0734 TrainAcc: 0.9817
# Epoch 27 ValLoss: 0.3258 ValAcc: 0.8519
#
# Epoch 28 TrainLoss: 0.0726 TrainAcc: 0.9817
# Epoch 28 ValLoss: 0.6180 ValAcc: 0.7593
#
# Epoch 29 TrainLoss: 0.0471 TrainAcc: 0.9878
# Epoch 29 ValLoss: 0.3333 ValAcc: 0.8333
#
# Epoch 30 TrainLoss: 0.1033 TrainAcc: 0.9573
# Epoch 30 ValLoss: 0.3868 ValAcc: 0.8333
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\0517Data\Weights\30\model_weights20240517_1334.pth
#
# Epoch 31 TrainLoss: 0.0782 TrainAcc: 0.9756
# Epoch 31 ValLoss: 0.3210 ValAcc: 0.8519
#
# Epoch 32 TrainLoss: 0.0755 TrainAcc: 0.9756
# Epoch 32 ValLoss: 0.3446 ValAcc: 0.8519
#
# Epoch 33 TrainLoss: 0.0810 TrainAcc: 0.9756
# Epoch 33 ValLoss: 0.3377 ValAcc: 0.8704
#
# Epoch 34 TrainLoss: 0.0432 TrainAcc: 0.9878
# Epoch 34 ValLoss: 0.3184 ValAcc: 0.9259
#
# Epoch 35 TrainLoss: 0.0248 TrainAcc: 1.0000
# Epoch 35 ValLoss: 0.3656 ValAcc: 0.9259
#
# Epoch 36 TrainLoss: 0.0207 TrainAcc: 0.9939
# Epoch 36 ValLoss: 0.2691 ValAcc: 0.9074
#
# Epoch 37 TrainLoss: 0.0463 TrainAcc: 0.9878
# Epoch 37 ValLoss: 0.2338 ValAcc: 0.8889
#
# Epoch 38 TrainLoss: 0.0221 TrainAcc: 1.0000
# Epoch 38 ValLoss: 0.3633 ValAcc: 0.8333
#
# Epoch 39 TrainLoss: 0.0131 TrainAcc: 1.0000
# Epoch 39 ValLoss: 0.2693 ValAcc: 0.8889
#
# Epoch 40 TrainLoss: 0.0106 TrainAcc: 1.0000
# Epoch 40 ValLoss: 0.2264 ValAcc: 0.9074
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\0517Data\Weights\40\model_weights20240517_1334.pth
#
# Epoch 41 TrainLoss: 0.0232 TrainAcc: 0.9939
# Epoch 41 ValLoss: 0.2756 ValAcc: 0.8889
#
# Epoch 42 TrainLoss: 0.0096 TrainAcc: 1.0000
# Epoch 42 ValLoss: 0.3919 ValAcc: 0.8333
#
# Epoch 43 TrainLoss: 0.0164 TrainAcc: 1.0000
# Epoch 43 ValLoss: 0.2391 ValAcc: 0.9444
#
# Epoch 44 TrainLoss: 0.0128 TrainAcc: 1.0000
# Epoch 44 ValLoss: 0.2475 ValAcc: 0.8889
#
# Epoch 45 TrainLoss: 0.0095 TrainAcc: 1.0000
# Epoch 45 ValLoss: 0.2911 ValAcc: 0.8519
#
# Epoch 46 TrainLoss: 0.0206 TrainAcc: 0.9878
# Epoch 46 ValLoss: 0.3746 ValAcc: 0.8704
#
# Epoch 47 TrainLoss: 0.0297 TrainAcc: 0.9939
# Epoch 47 ValLoss: 0.2734 ValAcc: 0.9074
#
# Epoch 48 TrainLoss: 0.0770 TrainAcc: 0.9756
# Epoch 48 ValLoss: 0.3472 ValAcc: 0.8704
#
# Epoch 49 TrainLoss: 0.0220 TrainAcc: 0.9878
# Epoch 49 ValLoss: 0.2874 ValAcc: 0.8889
#
# Epoch 50 TrainLoss: 0.0198 TrainAcc: 1.0000
# Epoch 50 ValLoss: 0.3488 ValAcc: 0.9074
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\0517Data\Weights\50\model_weights20240517_1334.pth
#
# Epoch 51 TrainLoss: 0.0139 TrainAcc: 0.9939
# Epoch 51 ValLoss: 0.2086 ValAcc: 0.9444
#
# Epoch 52 TrainLoss: 0.0050 TrainAcc: 1.0000
# Epoch 52 ValLoss: 0.2709 ValAcc: 0.9259
#
# Epoch 53 TrainLoss: 0.0191 TrainAcc: 0.9939
# Epoch 53 ValLoss: 0.3840 ValAcc: 0.9259
#
# Epoch 54 TrainLoss: 0.0247 TrainAcc: 0.9878
# Epoch 54 ValLoss: 0.3297 ValAcc: 0.8519
#
# Epoch 55 TrainLoss: 0.0122 TrainAcc: 1.0000
# Epoch 55 ValLoss: 0.3482 ValAcc: 0.9074
#
# Epoch 56 TrainLoss: 0.0297 TrainAcc: 0.9939
# Epoch 56 ValLoss: 0.4349 ValAcc: 0.8889
#
# Epoch 57 TrainLoss: 0.0188 TrainAcc: 0.9939
# Epoch 57 ValLoss: 0.4231 ValAcc: 0.8704
#
# Epoch 58 TrainLoss: 0.0111 TrainAcc: 1.0000
# Epoch 58 ValLoss: 0.5055 ValAcc: 0.8889
#
# Epoch 59 TrainLoss: 0.0149 TrainAcc: 0.9939
# Epoch 59 ValLoss: 0.4753 ValAcc: 0.8889
#
# Epoch 60 TrainLoss: 0.0087 TrainAcc: 1.0000
# Epoch 60 ValLoss: 0.4916 ValAcc: 0.8704
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\0517Data\Weights\60\model_weights20240517_1334.pth
#
# Epoch 61 TrainLoss: 0.0173 TrainAcc: 0.9939
# Epoch 61 ValLoss: 0.4317 ValAcc: 0.9074
#
# Epoch 62 TrainLoss: 0.0624 TrainAcc: 0.9878
# Epoch 62 ValLoss: 0.5068 ValAcc: 0.8704
#
# Epoch 63 TrainLoss: 0.0127 TrainAcc: 1.0000
# Epoch 63 ValLoss: 0.4587 ValAcc: 0.8889
#
# Epoch 64 TrainLoss: 0.0193 TrainAcc: 0.9939
# Epoch 64 ValLoss: 0.3900 ValAcc: 0.9074
#
# Epoch 65 TrainLoss: 0.0116 TrainAcc: 1.0000
# Epoch 65 ValLoss: 0.4445 ValAcc: 0.8889
#
# Epoch 66 TrainLoss: 0.0089 TrainAcc: 1.0000
# Epoch 66 ValLoss: 0.3860 ValAcc: 0.9259
#
# Epoch 67 TrainLoss: 0.0110 TrainAcc: 0.9939
# Epoch 67 ValLoss: 0.4517 ValAcc: 0.9074
#
# Epoch 68 TrainLoss: 0.0078 TrainAcc: 1.0000
# Epoch 68 ValLoss: 0.4684 ValAcc: 0.9074
#
# Epoch 69 TrainLoss: 0.0038 TrainAcc: 1.0000
# Epoch 69 ValLoss: 0.4808 ValAcc: 0.8889
#
# Epoch 70 TrainLoss: 0.0065 TrainAcc: 1.0000
# Epoch 70 ValLoss: 0.4286 ValAcc: 0.8704
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\0517Data\Weights\70\model_weights20240517_1334.pth
#
# Epoch 71 TrainLoss: 0.0129 TrainAcc: 0.9939
# Epoch 71 ValLoss: 0.4284 ValAcc: 0.8889
#
# Epoch 72 TrainLoss: 0.0038 TrainAcc: 1.0000
# Epoch 72 ValLoss: 0.4306 ValAcc: 0.8889
#
# Epoch 73 TrainLoss: 0.0209 TrainAcc: 0.9939
# Epoch 73 ValLoss: 0.3099 ValAcc: 0.9074
#
# Epoch 74 TrainLoss: 0.0193 TrainAcc: 0.9939
# Epoch 74 ValLoss: 0.5311 ValAcc: 0.8704
#
# Epoch 75 TrainLoss: 0.0156 TrainAcc: 0.9939
# Epoch 75 ValLoss: 0.4083 ValAcc: 0.8519
#
# Epoch 76 TrainLoss: 0.0118 TrainAcc: 1.0000
# Epoch 76 ValLoss: 0.4035 ValAcc: 0.8704
#
# Epoch 77 TrainLoss: 0.0096 TrainAcc: 0.9939
# Epoch 77 ValLoss: 0.3374 ValAcc: 0.9074
#
# Epoch 78 TrainLoss: 0.0054 TrainAcc: 1.0000
# Epoch 78 ValLoss: 0.3610 ValAcc: 0.9074
#
# Epoch 79 TrainLoss: 0.0018 TrainAcc: 1.0000
# Epoch 79 ValLoss: 0.3256 ValAcc: 0.9074
#
# Epoch 80 TrainLoss: 0.0038 TrainAcc: 1.0000
# Epoch 80 ValLoss: 0.3817 ValAcc: 0.9444
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\0517Data\Weights\80\model_weights20240517_1334.pth
#
# Epoch 81 TrainLoss: 0.0059 TrainAcc: 1.0000
# Epoch 81 ValLoss: 0.3213 ValAcc: 0.9259
#
# Epoch 82 TrainLoss: 0.0025 TrainAcc: 1.0000
# Epoch 82 ValLoss: 0.3450 ValAcc: 0.9259
#
# Epoch 83 TrainLoss: 0.0143 TrainAcc: 0.9939
# Epoch 83 ValLoss: 0.3847 ValAcc: 0.9259
#
# Epoch 84 TrainLoss: 0.0055 TrainAcc: 1.0000
# Epoch 84 ValLoss: 0.3522 ValAcc: 0.9259
#
# Epoch 85 TrainLoss: 0.0215 TrainAcc: 0.9939
# Epoch 85 ValLoss: 0.3522 ValAcc: 0.9259
#
# Epoch 86 TrainLoss: 0.0148 TrainAcc: 0.9939
# Epoch 86 ValLoss: 0.3189 ValAcc: 0.9074
#
# Epoch 87 TrainLoss: 0.0083 TrainAcc: 1.0000
# Epoch 87 ValLoss: 0.3494 ValAcc: 0.9259
#
# Epoch 88 TrainLoss: 0.0223 TrainAcc: 0.9939
# Epoch 88 ValLoss: 0.3187 ValAcc: 0.9259
#
# Epoch 89 TrainLoss: 0.0295 TrainAcc: 0.9939
# Epoch 89 ValLoss: 0.4116 ValAcc: 0.9259
#
# Epoch 90 TrainLoss: 0.0107 TrainAcc: 1.0000
# Epoch 90 ValLoss: 0.3873 ValAcc: 0.9259
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\0517Data\Weights\90\model_weights20240517_1334.pth
#
# Epoch 91 TrainLoss: 0.0339 TrainAcc: 0.9878
# Epoch 91 ValLoss: 0.5727 ValAcc: 0.8333
#
# Epoch 92 TrainLoss: 0.0077 TrainAcc: 1.0000
# Epoch 92 ValLoss: 0.4295 ValAcc: 0.9074
#
# Epoch 93 TrainLoss: 0.0193 TrainAcc: 0.9939
# Epoch 93 ValLoss: 0.3848 ValAcc: 0.9074
#
# Epoch 94 TrainLoss: 0.0169 TrainAcc: 0.9878
# Epoch 94 ValLoss: 0.6111 ValAcc: 0.8333
#
# Epoch 95 TrainLoss: 0.0082 TrainAcc: 0.9939
# Epoch 95 ValLoss: 0.5526 ValAcc: 0.8704
#
# Epoch 96 TrainLoss: 0.0116 TrainAcc: 1.0000
# Epoch 96 ValLoss: 0.4011 ValAcc: 0.9259
#
# Epoch 97 TrainLoss: 0.0169 TrainAcc: 0.9939
# Epoch 97 ValLoss: 0.4203 ValAcc: 0.8704
#
# Epoch 98 TrainLoss: 0.0059 TrainAcc: 1.0000
# Epoch 98 ValLoss: 0.3703 ValAcc: 0.9074
#
# Epoch 99 TrainLoss: 0.0129 TrainAcc: 1.0000
# Epoch 99 ValLoss: 0.3215 ValAcc: 0.9259
#
# Epoch 100 TrainLoss: 0.0055 TrainAcc: 1.0000
# Epoch 100 ValLoss: 0.3856 ValAcc: 0.8889
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\0517Data\Weights\100\model_weights20240517_1334.pth
#
# Epoch 101 TrainLoss: 0.0211 TrainAcc: 0.9939
# Epoch 101 ValLoss: 0.3763 ValAcc: 0.8704
#
# Epoch 102 TrainLoss: 0.0376 TrainAcc: 0.9817
# Epoch 102 ValLoss: 0.3357 ValAcc: 0.8889
#
# Epoch 103 TrainLoss: 0.1314 TrainAcc: 0.9878
# Epoch 103 ValLoss: 0.2661 ValAcc: 0.9259
#
# Epoch 104 TrainLoss: 0.0292 TrainAcc: 0.9939
# Epoch 104 ValLoss: 0.4942 ValAcc: 0.7963
#
# Epoch 105 TrainLoss: 0.0158 TrainAcc: 1.0000
# Epoch 105 ValLoss: 0.5969 ValAcc: 0.7963
#
# Epoch 106 TrainLoss: 0.0913 TrainAcc: 0.9878
# Epoch 106 ValLoss: 0.4324 ValAcc: 0.8889
#
# Epoch 107 TrainLoss: 0.0355 TrainAcc: 0.9939
# Epoch 107 ValLoss: 0.3572 ValAcc: 0.8704
#
# Epoch 108 TrainLoss: 0.0169 TrainAcc: 0.9939
# Epoch 108 ValLoss: 0.3264 ValAcc: 0.8889
#
# Epoch 109 TrainLoss: 0.0138 TrainAcc: 0.9939
# Epoch 109 ValLoss: 0.3958 ValAcc: 0.8704
#
# Epoch 110 TrainLoss: 0.0141 TrainAcc: 0.9939
# Epoch 110 ValLoss: 0.2956 ValAcc: 0.8889
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\0517Data\Weights\110\model_weights20240517_1334.pth
#
# Epoch 111 TrainLoss: 0.0123 TrainAcc: 0.9939
# Epoch 111 ValLoss: 0.3066 ValAcc: 0.8704
#
# Epoch 112 TrainLoss: 0.0045 TrainAcc: 1.0000
# Epoch 112 ValLoss: 0.3324 ValAcc: 0.8704
#
# Epoch 113 TrainLoss: 0.0055 TrainAcc: 1.0000
# Epoch 113 ValLoss: 0.3592 ValAcc: 0.8704
#
# Epoch 114 TrainLoss: 0.0140 TrainAcc: 0.9939
# Epoch 114 ValLoss: 0.4173 ValAcc: 0.8704
#
# Epoch 115 TrainLoss: 0.0148 TrainAcc: 0.9939
# Epoch 115 ValLoss: 0.5115 ValAcc: 0.8519
#
# Epoch 116 TrainLoss: 0.0037 TrainAcc: 1.0000
# Epoch 116 ValLoss: 0.4110 ValAcc: 0.8519
#
# Epoch 117 TrainLoss: 0.0212 TrainAcc: 0.9939
# Epoch 117 ValLoss: 0.3415 ValAcc: 0.8704
#
# Epoch 118 TrainLoss: 0.0076 TrainAcc: 1.0000
# Epoch 118 ValLoss: 0.3859 ValAcc: 0.8519
#
# Epoch 119 TrainLoss: 0.0085 TrainAcc: 1.0000
# Epoch 119 ValLoss: 0.3888 ValAcc: 0.8704
#
# Epoch 120 TrainLoss: 0.0283 TrainAcc: 0.9939
# Epoch 120 ValLoss: 0.4085 ValAcc: 0.8889
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\0517Data\Weights\120\model_weights20240517_1334.pth
#
# CSVs saved in C:\Users\kyohe\Aerial-Photo-Classifier\0517Data\History\20240517_1334
# Training Finished!!!
