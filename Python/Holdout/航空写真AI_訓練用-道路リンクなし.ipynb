# %%
import datetime
dt_now = datetime.datetime.now()
print(dt_now.strftime('%Y%m%d_%H%M'))
# Out:
# 20231219_1038

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import torch
import torch.nn as nn

# モデルの出力（予測された確率）
output = torch.randn(1, requires_grad=True)  # 例えば、モデルの出力をランダムに生成

# 正解ラベル（0または1）
target = torch.tensor([1.0])  # 例えば、1のラベル

# BCE損失を計算
loss_fn = nn.BCELoss()
loss = loss_fn(torch.sigmoid(output), target)

print("BCE Loss:", loss.item())
# Out:
# BCE Loss: 0.6826429963111877

# %%
import glob
import os
import numpy as np
import torch
import torch.optim as optim
import torchvision.transforms.functional as TF
from torchvision.transforms import v2
import torchvision.models as models
import torch.nn as nn
import cv2
from torch.utils.data import Dataset
from pathlib import Path
from typing import List, Tuple
from torch.utils.data import DataLoader
from torch.utils.data import random_split
import matplotlib.pyplot as plt
import datetime
import pandas as pd
import seaborn as sns; sns.set() # sns.set() ==> グラフの見た目をseabornに合わせる
# %matplotlib inline

time = datetime.datetime.now()
filedate=time.strftime('%Y%m%d_%H%M')

device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('cpu')

Channels=3
batch_size=8
epochs=200
IMG_SIZE=224
valsplit=0.25

Classes = ["Damaged", "Intact"]
ClassNum = len(Classes)

trainpath=r"C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\Train_SameSize_BrightContrast"
savepath=r"C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\Weights"
historypath=r"C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\History"

os.makedirs(savepath, exist_ok=True)
os.makedirs(historypath, exist_ok=True)

'''
PytorchではDataloaderという,膨大なデータセットからでもメモリを圧迫せずに取り出せてforループにも対応するための枠組みがある
データセットをDataloaderが引っ張ってこれるような形式にするためにMyDataset(torch.utils.data.Dataset)というクラスを作れば，
あとはそのメソッドをtorch.utils.data.Datasetが勝手に使用してデータを加工してくれる
__init__, __getitem__, __len__をクラス内で必ず定義しなければならない
Dataloader内のデータはバッチごとにまとめられる
'''
class MyDataset(Dataset):
    def __init__(self, root: str, transforms, Classes) -> None:
        super().__init__()
        self.transforms = transforms
        self.Classes = Classes
        #globは複数のファイルのパスをまとめて取得する
        #訓練と訓練白黒の二個下のディレクトリから画像を取得
        self.data = list(sorted(Path(root).glob("*\*")))

    #__getitem__は，MyDataset型のインスタンスでdataset[1]みたいに要素番号呼び出しをされたときに自動で行う処理(Pythonデフォ付属)
    # ここで取り出すデータを指定している
    def __getitem__(self, index: int) -> Tuple[torch.Tensor, torch.Tensor]:
        data = self.data[index]
        #OpenCVで読み込むときは必ずRGBに変換
        img1 = cv2.cvtColor(cv2.imread(str(data)), cv2.COLOR_BGR2RGB)
        img1 = cv2.resize(img1, (IMG_SIZE, IMG_SIZE))
        img1 = TF.to_tensor(img1)

        # データの変形 (transforms)
        transformed_img = self.transforms(img1)

        #ラベル貼り：dataというパスを/で区切ってリストにし，クラス名のところをラベルに格納
        #クラス名は文字列なので，self.Classesの要素と比較して一致するところの番号をラベルとする
        label = str(data).split("\\")[-2]
        label = torch.tensor(self.Classes.index(label))

        return transformed_img, label

    # この method がないと DataLoader を呼び出す際にエラーを吐かれる
    def __len__(self) -> int:
        return len(self.data)


#入力データに施す処理
transforms = v2.Compose([
        #v2.RandomHorizontalFlip(p=0.5),
        v2.ToDtype(torch.float32, scale=True),
        v2.Normalize(mean=[0,0,0], std=[0.2, 0.2, 0.2]),
])


trainvalset = MyDataset(root=trainpath, transforms=transforms, Classes=Classes)
trainset, valset = random_split(trainvalset, [1-valsplit, valsplit])

trainloader = DataLoader(dataset=trainset,batch_size=batch_size,shuffle=True)
valloader = DataLoader(dataset=valset,batch_size=batch_size,shuffle=True)


resnet50 = models.resnet50(weights='DEFAULT')

#チャンネル数いじれるようにしておく
resnet50.conv1 = torch.nn.Conv2d(Channels,64,kernel_size = (7,7),stride = (2,2), padding = (3,3), bias = False)
num_ftrs = resnet50.fc.in_features
#modifying final layer
resnet50.fc = nn.Linear(num_ftrs,ClassNum)

#GPUにニューラルネットワークを渡す
resnet50=resnet50.to(device)

#lossfunction&optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.SGD(resnet50.parameters(), lr=0.001, momentum=0.9)

print("Device:", device, "IMGSIZE:(", Channels, IMG_SIZE, IMG_SIZE, ")",  "BatchSize:", batch_size, "Epochs:", epochs, "Valsplit:", valsplit, "Class:", Classes, "Final Layer Nodes:", num_ftrs)

'''
trainiterator
enumerateはtrainloader内のすべてのdataに対してループし，繰り返し回数をbatchに渡すという意味
Dataloader内ではバッチごとにデータがまとめられるので1回の取り出しで1バッチ分のデータを丸々取り出せる
'''
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

def train(trainloader, valloader, model, loss_fn, optimizer, epochs):
    size = len(trainloader.dataset)
    num_batches = len(trainloader)
    size_val = len(valloader.dataset)
    num_batches_val = len(valloader)
    print("TrainData Size:", size, "TrainData Batches", num_batches, "ValData Size:", size_val, "ValData Batches:", num_batches_val)
    for epoch in range(epochs):
        running_loss, running_correct = 0, 0
        val_loss, val_correct = 0, 0
        for batch, (X, y) in enumerate(trainloader):
            X=X.to(device)
            y=y.to(device)
            # Compute prediction and loss
            pred = model(X)
            loss = loss_fn(pred, y)

            # Backpropagation
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

            #損失と正解数の合計を計算しておき，後でそのエポック内での平均をとる
            running_loss += loss.item()
            running_correct += (pred.argmax(1) == y).type(torch.float).sum().item()

        epoch_loss = running_loss / num_batches
        epoch_acc = running_correct / size

        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_acc)

        print(f'Epoch {epoch + 1} TrainLoss: {epoch_loss:.4f} TrainAcc: {epoch_acc:.4f}')

        # Set the model to evaluation mode - important for batch normalization and dropout layers
        model.eval()
        # Evaluating the model with torch.no_grad() ensures that no gradients are computed during test mode
        # also serves to reduce unnecessary gradient computations and memory usage for tensors with requires_grad=True
        with torch.no_grad():
            for X, y in valloader:
                X=X.to(device)
                y=y.to(device)
                pred = model(X)
                val_loss += loss_fn(pred, y).item()
                val_correct += (pred.argmax(1) == y).type(torch.float).sum().item()

            val_loss /= num_batches_val
            val_correct /= size_val
        # Set the model to train mode
        model.train()

        val_losses.append(val_loss)
        val_accuracies.append(val_correct)

        print(f'Epoch {epoch + 1} ValLoss: {val_loss:.4f} ValAcc: {val_correct:.4f}')

        #10epoch毎にパラメータを別々のフォルダに保存
        e1=epoch+1
        if (e1 % 10 == 0):
            savepath2 = Path(savepath+"\\"+str(e1)+"\model_weights"+filedate+".pth")
            os.makedirs(savepath2, exist_ok=True)
            print('Saving Model...')
            torch.save(model.state_dict(), savepath2)
            print('Model saved in', savepath2)

        print(' ')

train(trainloader, valloader, resnet50, loss_fn, optimizer, epochs)

#グラフ可視化
#pltの(x,y)のxにあたるepochのリスト　1から開始
ep=np.arange(1, epochs+1)

#グラフにプロットする正解率と損失のリストをCSVに書き出し to_csvは新規フォルダを作ってくれないのでosで作る
historypath2 = str(Path(historypath+"\\"+filedate))
os.mkdir(historypath2)
pd.DataFrame(data=np.array([ep, train_accuracies]).T, columns=["Epoch", "Accuracy"]).to_csv(Path(historypath2+"\\"+"Train_Acc.csv"))
pd.DataFrame(data=np.array([ep, train_losses]).T, columns=["Epoch", "Loss"]).to_csv(Path(historypath2+"\\"+"Train_Loss.csv"))
pd.DataFrame(data=np.array([ep, val_accuracies]).T, columns=["Epoch", "Accuracy"]).to_csv(Path(historypath2+"\\"+"Val_Acc.csv"))
pd.DataFrame(data=np.array([ep, val_losses]).T, columns=["Epoch", "Loss"]).to_csv(Path(historypath2+"\\"+"Val_Loss.csv"))
print("CSVs saved in", historypath2)

def plot_acc(train_accuracies, val_accuracies):
    plt.plot(ep, train_accuracies)
    plt.plot(ep, val_accuracies)
    plt.title("model accuracy")
    plt.ylabel("accuracy")
    plt.xlabel("epoch")
    plt.xticks(np.arange(0, epochs+1, 10))
    plt.yticks(np.arange(0.0, 1.05, 0.05))
    plt.legend(["train", "validation"], loc="lower right")
    plt.show()

def plot_loss(train_losses, val_losses):
    plt.plot(ep, train_losses)
    plt.plot(ep, val_losses)
    plt.title("model loss")
    plt.ylabel("loss")
    plt.xlabel("epoch")
    plt.xticks(np.arange(0, epochs+1, 10))
    plt.ylim(bottom=-5, top=10)
    plt.legend(["train", "validation"], loc="upper right")
    plt.show()

plot_acc(train_accuracies, val_accuracies)
plot_loss(train_losses, val_losses)

print('Training Finished!!!')
# Out:
# Device: cuda:0 IMGSIZE:( 3 224 224 ) BatchSize: 8 Epochs: 120 Valsplit: 0.25 Class: ['Damage', 'NoDamage'] Final Layer Nodes: 2048
# TrainData Size: 1647 TrainData Batches 206 ValData Size: 549 ValData Batches: 69
# Epoch 1 TrainLoss: 0.6626 TrainAcc: 0.5944
# Epoch 1 ValLoss: 0.6314 ValAcc: 0.5993
#
# Epoch 2 TrainLoss: 0.5225 TrainAcc: 0.7377
# Epoch 2 ValLoss: 0.5546 ValAcc: 0.7049
#
# Epoch 3 TrainLoss: 0.3229 TrainAcc: 0.8670
# Epoch 3 ValLoss: 0.2797 ValAcc: 0.8889
#
# Epoch 4 TrainLoss: 0.2140 TrainAcc: 0.9144
# Epoch 4 ValLoss: 0.1509 ValAcc: 0.9362
#
# Epoch 5 TrainLoss: 0.0936 TrainAcc: 0.9709
# Epoch 5 ValLoss: 0.0973 ValAcc: 0.9636
#
# Epoch 6 TrainLoss: 0.0981 TrainAcc: 0.9636
# Epoch 6 ValLoss: 0.0773 ValAcc: 0.9763
#
# Epoch 7 TrainLoss: 0.0699 TrainAcc: 0.9769
# Epoch 7 ValLoss: 0.0405 ValAcc: 0.9854
#
# Epoch 8 TrainLoss: 0.0561 TrainAcc: 0.9800
# Epoch 8 ValLoss: 0.0352 ValAcc: 0.9872
#
# Epoch 9 TrainLoss: 0.0389 TrainAcc: 0.9860
# Epoch 9 ValLoss: 0.0313 ValAcc: 0.9909
#
# Epoch 10 TrainLoss: 0.0336 TrainAcc: 0.9885
# Epoch 10 ValLoss: 0.0358 ValAcc: 0.9927
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\Weights\10\model_weights20250408_1035.pth
#
# Epoch 11 TrainLoss: 0.0303 TrainAcc: 0.9921
# Epoch 11 ValLoss: 0.0255 ValAcc: 0.9909
#
# Epoch 12 TrainLoss: 0.0139 TrainAcc: 0.9964
# Epoch 12 ValLoss: 0.0038 ValAcc: 1.0000
#
# Epoch 13 TrainLoss: 0.0120 TrainAcc: 0.9982
# Epoch 13 ValLoss: 0.0050 ValAcc: 1.0000
#
# Epoch 14 TrainLoss: 0.0070 TrainAcc: 0.9988
# Epoch 14 ValLoss: 0.0143 ValAcc: 0.9909
#
# Epoch 15 TrainLoss: 0.0131 TrainAcc: 0.9939
# Epoch 15 ValLoss: 0.0065 ValAcc: 1.0000
#
# Epoch 16 TrainLoss: 0.0081 TrainAcc: 0.9982
# Epoch 16 ValLoss: 0.0025 ValAcc: 1.0000
#
# Epoch 17 TrainLoss: 0.0129 TrainAcc: 0.9970
# Epoch 17 ValLoss: 0.0198 ValAcc: 0.9964
#
# Epoch 18 TrainLoss: 0.0130 TrainAcc: 0.9964
# Epoch 18 ValLoss: 0.0028 ValAcc: 1.0000
#
# Epoch 19 TrainLoss: 0.0110 TrainAcc: 0.9957
# Epoch 19 ValLoss: 0.0199 ValAcc: 0.9927
#
# Epoch 20 TrainLoss: 0.0159 TrainAcc: 0.9964
# Epoch 20 ValLoss: 0.0037 ValAcc: 1.0000
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\Weights\20\model_weights20250408_1035.pth
#
# Epoch 21 TrainLoss: 0.0088 TrainAcc: 0.9982
# Epoch 21 ValLoss: 0.0035 ValAcc: 1.0000
#
# Epoch 22 TrainLoss: 0.0014 TrainAcc: 1.0000
# Epoch 22 ValLoss: 0.0010 ValAcc: 1.0000
#
# Epoch 23 TrainLoss: 0.0044 TrainAcc: 0.9988
# Epoch 23 ValLoss: 0.0155 ValAcc: 0.9982
#
# Epoch 24 TrainLoss: 0.0057 TrainAcc: 0.9988
# Epoch 24 ValLoss: 0.0021 ValAcc: 1.0000
#
# Epoch 25 TrainLoss: 0.0071 TrainAcc: 0.9982
# Epoch 25 ValLoss: 0.0161 ValAcc: 0.9982
#
# Epoch 26 TrainLoss: 0.0048 TrainAcc: 0.9988
# Epoch 26 ValLoss: 0.0021 ValAcc: 1.0000
#
# Epoch 27 TrainLoss: 0.0050 TrainAcc: 0.9982
# Epoch 27 ValLoss: 0.0016 ValAcc: 1.0000
#
# Epoch 28 TrainLoss: 0.0040 TrainAcc: 0.9988
# Epoch 28 ValLoss: 0.0013 ValAcc: 1.0000
#
# Epoch 29 TrainLoss: 0.0044 TrainAcc: 0.9982
# Epoch 29 ValLoss: 0.0036 ValAcc: 0.9982
#
# Epoch 30 TrainLoss: 0.0027 TrainAcc: 0.9988
# Epoch 30 ValLoss: 0.0010 ValAcc: 1.0000
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\Weights\30\model_weights20250408_1035.pth
#
# Epoch 31 TrainLoss: 0.0029 TrainAcc: 0.9994
# Epoch 31 ValLoss: 0.0006 ValAcc: 1.0000
#
# Epoch 32 TrainLoss: 0.0012 TrainAcc: 1.0000
# Epoch 32 ValLoss: 0.0008 ValAcc: 1.0000
#
# Epoch 33 TrainLoss: 0.0016 TrainAcc: 0.9994
# Epoch 33 ValLoss: 0.0006 ValAcc: 1.0000
#
# Epoch 34 TrainLoss: 0.0033 TrainAcc: 0.9988
# Epoch 34 ValLoss: 0.0009 ValAcc: 1.0000
#
# Epoch 35 TrainLoss: 0.0051 TrainAcc: 0.9988
# Epoch 35 ValLoss: 0.0046 ValAcc: 1.0000
#
# Epoch 36 TrainLoss: 0.0017 TrainAcc: 0.9994
# Epoch 36 ValLoss: 0.0015 ValAcc: 1.0000
#
# Epoch 37 TrainLoss: 0.0013 TrainAcc: 1.0000
# Epoch 37 ValLoss: 0.0013 ValAcc: 1.0000
#
# Epoch 38 TrainLoss: 0.0007 TrainAcc: 1.0000
# Epoch 38 ValLoss: 0.0016 ValAcc: 1.0000
#
# Epoch 39 TrainLoss: 0.0007 TrainAcc: 1.0000
# Epoch 39 ValLoss: 0.0010 ValAcc: 1.0000
#
# Epoch 40 TrainLoss: 0.0008 TrainAcc: 1.0000
# Epoch 40 ValLoss: 0.0003 ValAcc: 1.0000
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\Weights\40\model_weights20250408_1035.pth
#
# Epoch 41 TrainLoss: 0.0008 TrainAcc: 1.0000
# Epoch 41 ValLoss: 0.0004 ValAcc: 1.0000
#
# Epoch 42 TrainLoss: 0.0004 TrainAcc: 1.0000
# Epoch 42 ValLoss: 0.0003 ValAcc: 1.0000
#
# Epoch 43 TrainLoss: 0.0003 TrainAcc: 1.0000
# Epoch 43 ValLoss: 0.0007 ValAcc: 1.0000
#
# Epoch 44 TrainLoss: 0.0004 TrainAcc: 1.0000
# Epoch 44 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 45 TrainLoss: 0.0081 TrainAcc: 0.9976
# Epoch 45 ValLoss: 0.0017 ValAcc: 1.0000
#
# Epoch 46 TrainLoss: 0.0148 TrainAcc: 0.9939
# Epoch 46 ValLoss: 0.0129 ValAcc: 0.9945
#
# Epoch 47 TrainLoss: 0.0020 TrainAcc: 1.0000
# Epoch 47 ValLoss: 0.0014 ValAcc: 1.0000
#
# Epoch 48 TrainLoss: 0.0024 TrainAcc: 0.9994
# Epoch 48 ValLoss: 0.0076 ValAcc: 0.9982
#
# Epoch 49 TrainLoss: 0.0010 TrainAcc: 1.0000
# Epoch 49 ValLoss: 0.0026 ValAcc: 0.9982
#
# Epoch 50 TrainLoss: 0.0010 TrainAcc: 1.0000
# Epoch 50 ValLoss: 0.0004 ValAcc: 1.0000
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\Weights\50\model_weights20250408_1035.pth
#
# Epoch 51 TrainLoss: 0.0044 TrainAcc: 0.9988
# Epoch 51 ValLoss: 0.0033 ValAcc: 0.9982
#
# Epoch 52 TrainLoss: 0.0012 TrainAcc: 1.0000
# Epoch 52 ValLoss: 0.0004 ValAcc: 1.0000
#
# Epoch 53 TrainLoss: 0.0011 TrainAcc: 1.0000
# Epoch 53 ValLoss: 0.0004 ValAcc: 1.0000
#
# Epoch 54 TrainLoss: 0.0005 TrainAcc: 1.0000
# Epoch 54 ValLoss: 0.0005 ValAcc: 1.0000
#
# Epoch 55 TrainLoss: 0.0007 TrainAcc: 1.0000
# Epoch 55 ValLoss: 0.0004 ValAcc: 1.0000
#
# Epoch 56 TrainLoss: 0.0003 TrainAcc: 1.0000
# Epoch 56 ValLoss: 0.0003 ValAcc: 1.0000
#
# Epoch 57 TrainLoss: 0.0004 TrainAcc: 1.0000
# Epoch 57 ValLoss: 0.0003 ValAcc: 1.0000
#
# Epoch 58 TrainLoss: 0.0008 TrainAcc: 0.9994
# Epoch 58 ValLoss: 0.0008 ValAcc: 1.0000
#
# Epoch 59 TrainLoss: 0.0005 TrainAcc: 1.0000
# Epoch 59 ValLoss: 0.0003 ValAcc: 1.0000
#
# Epoch 60 TrainLoss: 0.0003 TrainAcc: 1.0000
# Epoch 60 ValLoss: 0.0003 ValAcc: 1.0000
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\Weights\60\model_weights20250408_1035.pth
#
# Epoch 61 TrainLoss: 0.0002 TrainAcc: 1.0000
# Epoch 61 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 62 TrainLoss: 0.0002 TrainAcc: 1.0000
# Epoch 62 ValLoss: 0.0004 ValAcc: 1.0000
#
# Epoch 63 TrainLoss: 0.0003 TrainAcc: 1.0000
# Epoch 63 ValLoss: 0.0002 ValAcc: 1.0000
#
# Epoch 64 TrainLoss: 0.0008 TrainAcc: 1.0000
# Epoch 64 ValLoss: 0.0003 ValAcc: 1.0000
#
# Epoch 65 TrainLoss: 0.0003 TrainAcc: 1.0000
# Epoch 65 ValLoss: 0.0002 ValAcc: 1.0000
#
# Epoch 66 TrainLoss: 0.0002 TrainAcc: 1.0000
# Epoch 66 ValLoss: 0.0003 ValAcc: 1.0000
#
# Epoch 67 TrainLoss: 0.0011 TrainAcc: 0.9994
# Epoch 67 ValLoss: 0.0002 ValAcc: 1.0000
#
# Epoch 68 TrainLoss: 0.0010 TrainAcc: 1.0000
# Epoch 68 ValLoss: 0.0003 ValAcc: 1.0000
#
# Epoch 69 TrainLoss: 0.0003 TrainAcc: 1.0000
# Epoch 69 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 70 TrainLoss: 0.0006 TrainAcc: 1.0000
# Epoch 70 ValLoss: 0.0002 ValAcc: 1.0000
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\Weights\70\model_weights20250408_1035.pth
#
# Epoch 71 TrainLoss: 0.0003 TrainAcc: 1.0000
# Epoch 71 ValLoss: 0.0003 ValAcc: 1.0000
#
# Epoch 72 TrainLoss: 0.0022 TrainAcc: 0.9994
# Epoch 72 ValLoss: 0.0021 ValAcc: 1.0000
#
# Epoch 73 TrainLoss: 0.0005 TrainAcc: 1.0000
# Epoch 73 ValLoss: 0.0005 ValAcc: 1.0000
#
# Epoch 74 TrainLoss: 0.0003 TrainAcc: 1.0000
# Epoch 74 ValLoss: 0.0004 ValAcc: 1.0000
#
# Epoch 75 TrainLoss: 0.0026 TrainAcc: 0.9994
# Epoch 75 ValLoss: 0.0005 ValAcc: 1.0000
#
# Epoch 76 TrainLoss: 0.0005 TrainAcc: 1.0000
# Epoch 76 ValLoss: 0.0003 ValAcc: 1.0000
#
# Epoch 77 TrainLoss: 0.0002 TrainAcc: 1.0000
# Epoch 77 ValLoss: 0.0006 ValAcc: 1.0000
#
# Epoch 78 TrainLoss: 0.0003 TrainAcc: 1.0000
# Epoch 78 ValLoss: 0.0007 ValAcc: 1.0000
#
# Epoch 79 TrainLoss: 0.0001 TrainAcc: 1.0000
# Epoch 79 ValLoss: 0.0006 ValAcc: 1.0000
#
# Epoch 80 TrainLoss: 0.0003 TrainAcc: 1.0000
# Epoch 80 ValLoss: 0.0004 ValAcc: 1.0000
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\Weights\80\model_weights20250408_1035.pth
#
# Epoch 81 TrainLoss: 0.0002 TrainAcc: 1.0000
# Epoch 81 ValLoss: 0.0004 ValAcc: 1.0000
#
# Epoch 82 TrainLoss: 0.0002 TrainAcc: 1.0000
# Epoch 82 ValLoss: 0.0003 ValAcc: 1.0000
#
# Epoch 83 TrainLoss: 0.0001 TrainAcc: 1.0000
# Epoch 83 ValLoss: 0.0010 ValAcc: 1.0000
#
# Epoch 84 TrainLoss: 0.0002 TrainAcc: 1.0000
# Epoch 84 ValLoss: 0.0004 ValAcc: 1.0000
#
# Epoch 85 TrainLoss: 0.0001 TrainAcc: 1.0000
# Epoch 85 ValLoss: 0.0004 ValAcc: 1.0000
#
# Epoch 86 TrainLoss: 0.0002 TrainAcc: 1.0000
# Epoch 86 ValLoss: 0.0003 ValAcc: 1.0000
#
# Epoch 87 TrainLoss: 0.0001 TrainAcc: 1.0000
# Epoch 87 ValLoss: 0.0002 ValAcc: 1.0000
#
# Epoch 88 TrainLoss: 0.0010 TrainAcc: 0.9994
# Epoch 88 ValLoss: 0.0002 ValAcc: 1.0000
#
# Epoch 89 TrainLoss: 0.0004 TrainAcc: 1.0000
# Epoch 89 ValLoss: 0.0002 ValAcc: 1.0000
#
# Epoch 90 TrainLoss: 0.0016 TrainAcc: 0.9994
# Epoch 90 ValLoss: 0.0008 ValAcc: 1.0000
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\Weights\90\model_weights20250408_1035.pth
#
# Epoch 91 TrainLoss: 0.0021 TrainAcc: 0.9988
# Epoch 91 ValLoss: 0.0003 ValAcc: 1.0000
#
# Epoch 92 TrainLoss: 0.0007 TrainAcc: 1.0000
# Epoch 92 ValLoss: 0.0002 ValAcc: 1.0000
#
# Epoch 93 TrainLoss: 0.0005 TrainAcc: 1.0000
# Epoch 93 ValLoss: 0.0055 ValAcc: 0.9982
#
# Epoch 94 TrainLoss: 0.0036 TrainAcc: 0.9994
# Epoch 94 ValLoss: 0.0063 ValAcc: 0.9982
#
# Epoch 95 TrainLoss: 0.0028 TrainAcc: 0.9988
# Epoch 95 ValLoss: 0.0017 ValAcc: 1.0000
#
# Epoch 96 TrainLoss: 0.0009 TrainAcc: 1.0000
# Epoch 96 ValLoss: 0.0054 ValAcc: 0.9982
#
# Epoch 97 TrainLoss: 0.0005 TrainAcc: 1.0000
# Epoch 97 ValLoss: 0.0002 ValAcc: 1.0000
#
# Epoch 98 TrainLoss: 0.0003 TrainAcc: 1.0000
# Epoch 98 ValLoss: 0.0002 ValAcc: 1.0000
#
# Epoch 99 TrainLoss: 0.0016 TrainAcc: 0.9994
# Epoch 99 ValLoss: 0.0004 ValAcc: 1.0000
#
# Epoch 100 TrainLoss: 0.0007 TrainAcc: 1.0000
# Epoch 100 ValLoss: 0.0002 ValAcc: 1.0000
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\Weights\100\model_weights20250408_1035.pth
#
# Epoch 101 TrainLoss: 0.0003 TrainAcc: 1.0000
# Epoch 101 ValLoss: 0.0020 ValAcc: 0.9982
#
# Epoch 102 TrainLoss: 0.0011 TrainAcc: 0.9994
# Epoch 102 ValLoss: 0.0007 ValAcc: 1.0000
#
# Epoch 103 TrainLoss: 0.0002 TrainAcc: 1.0000
# Epoch 103 ValLoss: 0.0002 ValAcc: 1.0000
#
# Epoch 104 TrainLoss: 0.0002 TrainAcc: 1.0000
# Epoch 104 ValLoss: 0.0002 ValAcc: 1.0000
#
# Epoch 105 TrainLoss: 0.0001 TrainAcc: 1.0000
# Epoch 105 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 106 TrainLoss: 0.0002 TrainAcc: 1.0000
# Epoch 106 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 107 TrainLoss: 0.0004 TrainAcc: 1.0000
# Epoch 107 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 108 TrainLoss: 0.0001 TrainAcc: 1.0000
# Epoch 108 ValLoss: 0.0002 ValAcc: 1.0000
#
# Epoch 109 TrainLoss: 0.0002 TrainAcc: 1.0000
# Epoch 109 ValLoss: 0.0017 ValAcc: 0.9982
#
# Epoch 110 TrainLoss: 0.0001 TrainAcc: 1.0000
# Epoch 110 ValLoss: 0.0002 ValAcc: 1.0000
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\Weights\110\model_weights20250408_1035.pth
#
# Epoch 111 TrainLoss: 0.0001 TrainAcc: 1.0000
# Epoch 111 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 112 TrainLoss: 0.0001 TrainAcc: 1.0000
# Epoch 112 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 113 TrainLoss: 0.0001 TrainAcc: 1.0000
# Epoch 113 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 114 TrainLoss: 0.0002 TrainAcc: 1.0000
# Epoch 114 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 115 TrainLoss: 0.0002 TrainAcc: 1.0000
# Epoch 115 ValLoss: 0.0005 ValAcc: 1.0000
#
# Epoch 116 TrainLoss: 0.0001 TrainAcc: 1.0000
# Epoch 116 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 117 TrainLoss: 0.0001 TrainAcc: 1.0000
# Epoch 117 ValLoss: 0.0002 ValAcc: 1.0000
#
# Epoch 118 TrainLoss: 0.0001 TrainAcc: 1.0000
# Epoch 118 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 119 TrainLoss: 0.0001 TrainAcc: 1.0000
# Epoch 119 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 120 TrainLoss: 0.0001 TrainAcc: 1.0000
# Epoch 120 ValLoss: 0.0001 ValAcc: 1.0000
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\Weights\120\model_weights20250408_1035.pth
#
# CSVs saved in C:\Users\kyohe\Aerial-Photo-Classifier\20241023Data\History\20250408_1035
# Training Finished!!!
