# %%
import datetime
dt_now = datetime.datetime.now()
print(dt_now.strftime('%Y%m%d_%H%M'))
# Out:
# 20231219_1038

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import torch
import torch.nn as nn

# モデルの出力（予測された確率）
output = torch.randn(1, requires_grad=True)  # 例えば、モデルの出力をランダムに生成

# 正解ラベル（0または1）
target = torch.tensor([1.0])  # 例えば、1のラベル

# BCE損失を計算
loss_fn = nn.BCELoss()
loss = loss_fn(torch.sigmoid(output), target)

print("BCE Loss:", loss.item())
# Out:
# BCE Loss: 0.6826429963111877

# %%
import glob
import os
import numpy as np
import torch
import torch.optim as optim
import torchvision.transforms.functional as TF
from torchvision.transforms import v2
import torchvision.models as models
import torch.nn as nn
import cv2
from torch.utils.data import Dataset
from pathlib import Path
from typing import List, Tuple
from torch.utils.data import DataLoader
from torch.utils.data import random_split
import matplotlib.pyplot as plt
import datetime
import pandas as pd
import seaborn as sns; sns.set() # sns.set() ==> グラフの見た目をseabornに合わせる
# %matplotlib inline

time = datetime.datetime.now()
filedate=time.strftime('%Y%m%d_%H%M')

device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('cpu')

Channels=3
batch_size=8
epochs=120
IMG_SIZE=224
valsplit=0.25

Classes = ["Damage", "NoDamage"]
ClassNum = len(Classes)

trainpath=r"C:\Users\kyohe\Aerial-Photo-Classifier\0522Data\Train"
savepath=r"C:\Users\kyohe\Aerial-Photo-Classifier\0522Data\Weights"
historypath=r"C:\Users\kyohe\Aerial-Photo-Classifier\0522Data\History"

'''
PytorchではDataloaderという,膨大なデータセットからでもメモリを圧迫せずに取り出せてforループにも対応するための枠組みがある
データセットをDataloaderが引っ張ってこれるような形式にするためにMyDataset(torch.utils.data.Dataset)というクラスを作れば，
あとはそのメソッドをtorch.utils.data.Datasetが勝手に使用してデータを加工してくれる
__init__, __getitem__, __len__をクラス内で必ず定義しなければならない
Dataloader内のデータはバッチごとにまとめられる
'''
class MyDataset(Dataset):
    def __init__(self, root: str, transforms, Classes) -> None:
        super().__init__()
        self.transforms = transforms
        self.Classes = Classes
        #globは複数のファイルのパスをまとめて取得する
        #訓練と訓練白黒の二個下のディレクトリから画像を取得
        self.data = list(sorted(Path(root).glob("*\*")))


    # ここで取り出すデータを指定している
    def __getitem__(self, index: int) -> Tuple[torch.Tensor, torch.Tensor]:
        data = self.data[index]

        img1 = cv2.imread(str(data))
        img1 = cv2.resize(img1, (IMG_SIZE, IMG_SIZE))
        img1 = TF.to_tensor(img1)

        # データの変形 (transforms)
        transformed_img = self.transforms(img1)

        #ラベル貼り：dataというパスを/で区切ってリストにし，クラス名のところをラベルに格納
        #クラス名は文字列なので，self.Classesの要素と比較して一致するところの番号をラベルとする
        label = str(data).split("\\")[-2]
        label = torch.tensor(self.Classes.index(label))

        return transformed_img, label

    # この method がないと DataLoader を呼び出す際にエラーを吐かれる
    def __len__(self) -> int:
        return len(self.data)


#入力データに施す処理
transforms = v2.Compose([
        #v2.RandomHorizontalFlip(p=0.5),
        v2.ToDtype(torch.float32, scale=True),
        v2.Normalize(mean=[0,0,0], std=[0.2, 0.2, 0.2]),
])


trainvalset = MyDataset(root=trainpath, transforms=transforms, Classes=Classes)
trainset, valset = random_split(trainvalset, [1-valsplit, valsplit])

trainloader = DataLoader(dataset=trainset,batch_size=batch_size,shuffle=True)
valloader = DataLoader(dataset=valset,batch_size=batch_size,shuffle=True)


resnet50 = models.resnet50(weights='DEFAULT')


resnet50.conv1 = torch.nn.Conv2d(Channels,64,kernel_size = (7,7),stride = (2,2), padding = (3,3), bias = False)
num_ftrs = resnet50.fc.in_features
#modifying final layer
resnet50.fc = nn.Linear(num_ftrs,ClassNum)

#GPUにニューラルネットワークを渡す
resnet50=resnet50.to(device)

#lossfunction&optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.SGD(resnet50.parameters(), lr=0.001, momentum=0.9)

print("Device:", device, "IMGSIZE:(", Channels, IMG_SIZE, IMG_SIZE, ")",  "BatchSize:", batch_size, "Epochs:", epochs, "Valsplit:", valsplit, "Class:", Classes, "Final Layer Nodes:", num_ftrs)

'''
trainiterator
enumerateはtrainloader内のすべてのdataに対してループし，繰り返し回数をbatchに渡すという意味
Dataloader内ではバッチごとにデータがまとめられるので1回の取り出しで1バッチ分のデータを丸々取り出せる
'''
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

def train(trainloader, valloader, model, loss_fn, optimizer, epochs):
    size = len(trainloader.dataset)
    num_batches = len(trainloader)
    size_val = len(valloader.dataset)
    num_batches_val = len(valloader)
    print("TrainData Size:", size, "TrainData Batches", num_batches, "ValData Size:", size_val, "ValData Batches:", num_batches_val)
    for epoch in range(epochs):
        running_loss, running_correct = 0, 0
        val_loss, val_correct = 0, 0
        for batch, (X, y) in enumerate(trainloader):
            X=X.to(device)
            y=y.to(device)
            # Compute prediction and loss
            pred = model(X)
            loss = loss_fn(pred, y)

            # Backpropagation
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

            #損失と正解数の合計を計算しておき，後でそのエポック内での平均をとる
            running_loss += loss.item()
            running_correct += (pred.argmax(1) == y).type(torch.float).sum().item()

        epoch_loss = running_loss / num_batches
        epoch_acc = running_correct / size

        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_acc)

        print(f'Epoch {epoch + 1} TrainLoss: {epoch_loss:.4f} TrainAcc: {epoch_acc:.4f}')

        # Set the model to evaluation mode - important for batch normalization and dropout layers
        model.eval()
        # Evaluating the model with torch.no_grad() ensures that no gradients are computed during test mode
        # also serves to reduce unnecessary gradient computations and memory usage for tensors with requires_grad=True
        with torch.no_grad():
            for X, y in valloader:
                X=X.to(device)
                y=y.to(device)
                pred = model(X)
                val_loss += loss_fn(pred, y).item()
                val_correct += (pred.argmax(1) == y).type(torch.float).sum().item()

            val_loss /= num_batches_val
            val_correct /= size_val
        # Set the model to train mode
        model.train()

        val_losses.append(val_loss)
        val_accuracies.append(val_correct)

        print(f'Epoch {epoch + 1} ValLoss: {val_loss:.4f} ValAcc: {val_correct:.4f}')

        #10epoch毎にパラメータを別々のフォルダに保存
        e1=epoch+1
        if (e1 % 10 == 0):
            savepath2 = Path(savepath+"\\"+str(e1)+"\model_weights"+filedate+".pth")
            print('Saving Model...')
            torch.save(model.state_dict(), savepath2)
            print('Model saved in', savepath2)

        print(' ')

train(trainloader, valloader, resnet50, loss_fn, optimizer, epochs)

#グラフ可視化
#pltの(x,y)のxにあたるepochのリスト　1から開始
ep=np.arange(1, epochs+1)

#グラフにプロットする正解率と損失のリストをCSVに書き出し to_csvは新規フォルダを作ってくれないのでosで作る
historypath2 = str(Path(historypath+"\\"+filedate))
os.mkdir(historypath2)
pd.DataFrame(data=np.array([ep, train_accuracies]).T, columns=["Epoch", "Accuracy"]).to_csv(Path(historypath2+"\\"+"Train_Acc.csv"))
pd.DataFrame(data=np.array([ep, train_losses]).T, columns=["Epoch", "Loss"]).to_csv(Path(historypath2+"\\"+"Train_Loss.csv"))
pd.DataFrame(data=np.array([ep, val_accuracies]).T, columns=["Epoch", "Accuracy"]).to_csv(Path(historypath2+"\\"+"Val_Acc.csv"))
pd.DataFrame(data=np.array([ep, val_losses]).T, columns=["Epoch", "Loss"]).to_csv(Path(historypath2+"\\"+"Val_Loss.csv"))
print("CSVs saved in", historypath2)

def plot_acc(train_accuracies, val_accuracies):
    plt.plot(ep, train_accuracies)
    plt.plot(ep, val_accuracies)
    plt.title("model accuracy")
    plt.ylabel("accuracy")
    plt.xlabel("epoch")
    plt.xticks(np.arange(0, epochs+1, 10))
    plt.yticks(np.arange(0.0, 1.05, 0.05))
    plt.legend(["train", "validation"], loc="lower right")
    plt.show()

def plot_loss(train_losses, val_losses):
    plt.plot(ep, train_losses)
    plt.plot(ep, val_losses)
    plt.title("model loss")
    plt.ylabel("loss")
    plt.xlabel("epoch")
    plt.xticks(np.arange(0, epochs+1, 10))
    plt.ylim(bottom=-5, top=10)
    plt.legend(["train", "validation"], loc="upper right")
    plt.show()

plot_acc(train_accuracies, val_accuracies)
plot_loss(train_losses, val_losses)

print('Training Finished!!!')
# Out:
# Device: cuda:0 IMGSIZE:( 3 224 224 ) BatchSize: 8 Epochs: 120 Valsplit: 0.25 Class: ['Damage', 'NoDamage'] Final Layer Nodes: 2048
# TrainData Size: 189 TrainData Batches 24 ValData Size: 63 ValData Batches: 8
# Epoch 1 TrainLoss: 0.6820 TrainAcc: 0.5185
# Epoch 1 ValLoss: 0.6820 ValAcc: 0.5238
#
# Epoch 2 TrainLoss: 0.6111 TrainAcc: 0.6878
# Epoch 2 ValLoss: 0.7026 ValAcc: 0.4603
#
# Epoch 3 TrainLoss: 0.5377 TrainAcc: 0.7937
# Epoch 3 ValLoss: 1.3632 ValAcc: 0.5397
#
# Epoch 4 TrainLoss: 0.4503 TrainAcc: 0.8095
# Epoch 4 ValLoss: 0.6802 ValAcc: 0.5556
#
# Epoch 5 TrainLoss: 0.4502 TrainAcc: 0.7619
# Epoch 5 ValLoss: 0.6285 ValAcc: 0.6032
#
# Epoch 6 TrainLoss: 0.4292 TrainAcc: 0.8095
# Epoch 6 ValLoss: 0.6308 ValAcc: 0.6667
#
# Epoch 7 TrainLoss: 0.3186 TrainAcc: 0.8836
# Epoch 7 ValLoss: 0.6670 ValAcc: 0.6032
#
# Epoch 8 TrainLoss: 0.2839 TrainAcc: 0.8889
# Epoch 8 ValLoss: 0.5902 ValAcc: 0.6825
#
# Epoch 9 TrainLoss: 0.2672 TrainAcc: 0.8942
# Epoch 9 ValLoss: 0.3713 ValAcc: 0.8730
#
# Epoch 10 TrainLoss: 0.2501 TrainAcc: 0.9048
# Epoch 10 ValLoss: 0.3985 ValAcc: 0.8413
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\0522Data\Weights\10\model_weights20240522_2036.pth
#
# Epoch 11 TrainLoss: 0.1961 TrainAcc: 0.9418
# Epoch 11 ValLoss: 0.2289 ValAcc: 0.9365
#
# Epoch 12 TrainLoss: 0.2221 TrainAcc: 0.9312
# Epoch 12 ValLoss: 0.3265 ValAcc: 0.8413
#
# Epoch 13 TrainLoss: 0.1591 TrainAcc: 0.9577
# Epoch 13 ValLoss: 0.3484 ValAcc: 0.8571
#
# Epoch 14 TrainLoss: 0.1231 TrainAcc: 0.9524
# Epoch 14 ValLoss: 0.3718 ValAcc: 0.7778
#
# Epoch 15 TrainLoss: 0.1172 TrainAcc: 0.9683
# Epoch 15 ValLoss: 0.3108 ValAcc: 0.9048
#
# Epoch 16 TrainLoss: 0.0771 TrainAcc: 0.9788
# Epoch 16 ValLoss: 0.2533 ValAcc: 0.9048
#
# Epoch 17 TrainLoss: 0.0821 TrainAcc: 0.9735
# Epoch 17 ValLoss: 0.1533 ValAcc: 0.9365
#
# Epoch 18 TrainLoss: 0.1091 TrainAcc: 0.9683
# Epoch 18 ValLoss: 0.2344 ValAcc: 0.8889
#
# Epoch 19 TrainLoss: 0.0842 TrainAcc: 0.9894
# Epoch 19 ValLoss: 0.2393 ValAcc: 0.8889
#
# Epoch 20 TrainLoss: 0.0731 TrainAcc: 0.9788
# Epoch 20 ValLoss: 0.1710 ValAcc: 0.9365
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\0522Data\Weights\20\model_weights20240522_2036.pth
#
# Epoch 21 TrainLoss: 0.0608 TrainAcc: 0.9788
# Epoch 21 ValLoss: 0.3119 ValAcc: 0.8730
#
# Epoch 22 TrainLoss: 0.0549 TrainAcc: 0.9841
# Epoch 22 ValLoss: 0.2795 ValAcc: 0.8889
#
# Epoch 23 TrainLoss: 0.0881 TrainAcc: 0.9841
# Epoch 23 ValLoss: 0.2872 ValAcc: 0.8889
#
# Epoch 24 TrainLoss: 0.0609 TrainAcc: 0.9841
# Epoch 24 ValLoss: 0.4481 ValAcc: 0.8413
#
# Epoch 25 TrainLoss: 0.0490 TrainAcc: 0.9788
# Epoch 25 ValLoss: 0.2057 ValAcc: 0.9365
#
# Epoch 26 TrainLoss: 0.0456 TrainAcc: 0.9894
# Epoch 26 ValLoss: 0.1929 ValAcc: 0.9048
#
# Epoch 27 TrainLoss: 0.0452 TrainAcc: 0.9841
# Epoch 27 ValLoss: 0.2036 ValAcc: 0.9206
#
# Epoch 28 TrainLoss: 0.0454 TrainAcc: 0.9841
# Epoch 28 ValLoss: 0.3388 ValAcc: 0.8571
#
# Epoch 29 TrainLoss: 0.0676 TrainAcc: 0.9735
# Epoch 29 ValLoss: 0.1615 ValAcc: 0.9048
#
# Epoch 30 TrainLoss: 0.1186 TrainAcc: 0.9577
# Epoch 30 ValLoss: 0.3007 ValAcc: 0.8730
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\0522Data\Weights\30\model_weights20240522_2036.pth
#
# Epoch 31 TrainLoss: 0.0355 TrainAcc: 0.9947
# Epoch 31 ValLoss: 0.2984 ValAcc: 0.9048
#
# Epoch 32 TrainLoss: 0.0230 TrainAcc: 1.0000
# Epoch 32 ValLoss: 0.1664 ValAcc: 0.9365
#
# Epoch 33 TrainLoss: 0.0194 TrainAcc: 0.9947
# Epoch 33 ValLoss: 0.1772 ValAcc: 0.9048
#
# Epoch 34 TrainLoss: 0.0633 TrainAcc: 0.9735
# Epoch 34 ValLoss: 0.3297 ValAcc: 0.9048
#
# Epoch 35 TrainLoss: 0.0417 TrainAcc: 0.9894
# Epoch 35 ValLoss: 0.3436 ValAcc: 0.9206
#
# Epoch 36 TrainLoss: 0.0481 TrainAcc: 0.9841
# Epoch 36 ValLoss: 0.2596 ValAcc: 0.9365
#
# Epoch 37 TrainLoss: 0.0286 TrainAcc: 0.9894
# Epoch 37 ValLoss: 0.1795 ValAcc: 0.9524
#
# Epoch 38 TrainLoss: 0.0187 TrainAcc: 1.0000
# Epoch 38 ValLoss: 0.1013 ValAcc: 0.9683
#
# Epoch 39 TrainLoss: 0.0584 TrainAcc: 0.9683
# Epoch 39 ValLoss: 0.2187 ValAcc: 0.9683
#
# Epoch 40 TrainLoss: 0.0269 TrainAcc: 0.9947
# Epoch 40 ValLoss: 0.2187 ValAcc: 0.9365
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\0522Data\Weights\40\model_weights20240522_2036.pth
#
# Epoch 41 TrainLoss: 0.0360 TrainAcc: 0.9894
# Epoch 41 ValLoss: 0.3299 ValAcc: 0.9048
#
# Epoch 42 TrainLoss: 0.0205 TrainAcc: 1.0000
# Epoch 42 ValLoss: 0.1800 ValAcc: 0.9524
#
# Epoch 43 TrainLoss: 0.0377 TrainAcc: 0.9841
# Epoch 43 ValLoss: 0.2039 ValAcc: 0.9365
#
# Epoch 44 TrainLoss: 0.0228 TrainAcc: 0.9947
# Epoch 44 ValLoss: 0.2886 ValAcc: 0.9048
#
# Epoch 45 TrainLoss: 0.0159 TrainAcc: 1.0000
# Epoch 45 ValLoss: 0.2113 ValAcc: 0.9206
#
# Epoch 46 TrainLoss: 0.0070 TrainAcc: 1.0000
# Epoch 46 ValLoss: 0.2418 ValAcc: 0.9206
#
# Epoch 47 TrainLoss: 0.0128 TrainAcc: 1.0000
# Epoch 47 ValLoss: 0.2017 ValAcc: 0.9365
#
# Epoch 48 TrainLoss: 0.0345 TrainAcc: 0.9894
# Epoch 48 ValLoss: 0.1454 ValAcc: 0.9365
#
# Epoch 49 TrainLoss: 0.0669 TrainAcc: 0.9894
# Epoch 49 ValLoss: 0.2350 ValAcc: 0.9365
#
# Epoch 50 TrainLoss: 0.0067 TrainAcc: 1.0000
# Epoch 50 ValLoss: 0.1711 ValAcc: 0.9524
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\0522Data\Weights\50\model_weights20240522_2036.pth
#
# Epoch 51 TrainLoss: 0.0153 TrainAcc: 0.9947
# Epoch 51 ValLoss: 0.2707 ValAcc: 0.9048
#
# Epoch 52 TrainLoss: 0.0079 TrainAcc: 1.0000
# Epoch 52 ValLoss: 0.2066 ValAcc: 0.9206
#
# Epoch 53 TrainLoss: 0.0108 TrainAcc: 1.0000
# Epoch 53 ValLoss: 0.2063 ValAcc: 0.9365
#
# Epoch 54 TrainLoss: 0.0399 TrainAcc: 0.9788
# Epoch 54 ValLoss: 0.1779 ValAcc: 0.9524
#
# Epoch 55 TrainLoss: 0.0070 TrainAcc: 1.0000
# Epoch 55 ValLoss: 0.1443 ValAcc: 0.9524
#
# Epoch 56 TrainLoss: 0.0228 TrainAcc: 0.9947
# Epoch 56 ValLoss: 0.3498 ValAcc: 0.8889
#
# Epoch 57 TrainLoss: 0.0309 TrainAcc: 0.9894
# Epoch 57 ValLoss: 0.2409 ValAcc: 0.9048
#
# Epoch 58 TrainLoss: 0.0204 TrainAcc: 0.9894
# Epoch 58 ValLoss: 0.2302 ValAcc: 0.9048
#
# Epoch 59 TrainLoss: 0.0103 TrainAcc: 1.0000
# Epoch 59 ValLoss: 0.1032 ValAcc: 0.9841
#
# Epoch 60 TrainLoss: 0.0102 TrainAcc: 1.0000
# Epoch 60 ValLoss: 0.1480 ValAcc: 0.9683
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\0522Data\Weights\60\model_weights20240522_2036.pth
#
# Epoch 61 TrainLoss: 0.0148 TrainAcc: 0.9947
# Epoch 61 ValLoss: 0.1560 ValAcc: 0.9524
#
# Epoch 62 TrainLoss: 0.0075 TrainAcc: 1.0000
# Epoch 62 ValLoss: 0.1372 ValAcc: 0.9841
#
# Epoch 63 TrainLoss: 0.0510 TrainAcc: 0.9788
# Epoch 63 ValLoss: 0.1933 ValAcc: 0.9365
#
# Epoch 64 TrainLoss: 0.0117 TrainAcc: 1.0000
# Epoch 64 ValLoss: 0.1069 ValAcc: 0.9524
#
# Epoch 65 TrainLoss: 0.0076 TrainAcc: 1.0000
# Epoch 65 ValLoss: 0.0844 ValAcc: 0.9841
#
# Epoch 66 TrainLoss: 0.0530 TrainAcc: 0.9788
# Epoch 66 ValLoss: 0.3101 ValAcc: 0.8889
#
# Epoch 67 TrainLoss: 0.0311 TrainAcc: 0.9947
# Epoch 67 ValLoss: 0.2649 ValAcc: 0.9206
#
# Epoch 68 TrainLoss: 0.0196 TrainAcc: 0.9947
# Epoch 68 ValLoss: 0.2230 ValAcc: 0.9365
#
# Epoch 69 TrainLoss: 0.0151 TrainAcc: 1.0000
# Epoch 69 ValLoss: 0.1765 ValAcc: 0.9365
#
# Epoch 70 TrainLoss: 0.0174 TrainAcc: 0.9947
# Epoch 70 ValLoss: 0.1647 ValAcc: 0.9683
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\0522Data\Weights\70\model_weights20240522_2036.pth
#
# Epoch 71 TrainLoss: 0.0759 TrainAcc: 0.9841
# Epoch 71 ValLoss: 0.1202 ValAcc: 0.9683
#
# Epoch 72 TrainLoss: 0.0064 TrainAcc: 1.0000
# Epoch 72 ValLoss: 0.1137 ValAcc: 0.9683
#
# Epoch 73 TrainLoss: 0.0208 TrainAcc: 0.9947
# Epoch 73 ValLoss: 0.1382 ValAcc: 0.9365
#
# Epoch 74 TrainLoss: 0.0196 TrainAcc: 0.9947
# Epoch 74 ValLoss: 0.1315 ValAcc: 0.9365
#
# Epoch 75 TrainLoss: 0.0173 TrainAcc: 0.9947
# Epoch 75 ValLoss: 0.1337 ValAcc: 0.9683
#
# Epoch 76 TrainLoss: 0.0099 TrainAcc: 1.0000
# Epoch 76 ValLoss: 0.1077 ValAcc: 0.9524
#
# Epoch 77 TrainLoss: 0.0302 TrainAcc: 0.9894
# Epoch 77 ValLoss: 0.4008 ValAcc: 0.8889
#
# Epoch 78 TrainLoss: 0.0053 TrainAcc: 1.0000
# Epoch 78 ValLoss: 0.1581 ValAcc: 0.9365
#
# Epoch 79 TrainLoss: 0.0096 TrainAcc: 0.9947
# Epoch 79 ValLoss: 0.1433 ValAcc: 0.9365
#
# Epoch 80 TrainLoss: 0.0098 TrainAcc: 1.0000
# Epoch 80 ValLoss: 0.0909 ValAcc: 0.9841
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\0522Data\Weights\80\model_weights20240522_2036.pth
#
# Epoch 81 TrainLoss: 0.0039 TrainAcc: 1.0000
# Epoch 81 ValLoss: 0.1002 ValAcc: 0.9683
#
# Epoch 82 TrainLoss: 0.0064 TrainAcc: 1.0000
# Epoch 82 ValLoss: 0.0701 ValAcc: 0.9841
#
# Epoch 83 TrainLoss: 0.0103 TrainAcc: 0.9947
# Epoch 83 ValLoss: 0.0954 ValAcc: 0.9841
#
# Epoch 84 TrainLoss: 0.0047 TrainAcc: 1.0000
# Epoch 84 ValLoss: 0.1310 ValAcc: 0.9683
#
# Epoch 85 TrainLoss: 0.0469 TrainAcc: 0.9841
# Epoch 85 ValLoss: 0.1144 ValAcc: 0.9365
#
# Epoch 86 TrainLoss: 0.0205 TrainAcc: 0.9947
# Epoch 86 ValLoss: 0.1600 ValAcc: 0.9683
#
# Epoch 87 TrainLoss: 0.0192 TrainAcc: 0.9947
# Epoch 87 ValLoss: 0.2442 ValAcc: 0.9048
#
# Epoch 88 TrainLoss: 0.0483 TrainAcc: 0.9788
# Epoch 88 ValLoss: 0.3478 ValAcc: 0.8095
#
# Epoch 89 TrainLoss: 0.0196 TrainAcc: 0.9947
# Epoch 89 ValLoss: 0.2118 ValAcc: 0.9524
#
# Epoch 90 TrainLoss: 0.0115 TrainAcc: 1.0000
# Epoch 90 ValLoss: 0.2078 ValAcc: 0.9365
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\0522Data\Weights\90\model_weights20240522_2036.pth
#
# Epoch 91 TrainLoss: 0.0191 TrainAcc: 0.9947
# Epoch 91 ValLoss: 0.2812 ValAcc: 0.9365
#
# Epoch 92 TrainLoss: 0.0468 TrainAcc: 0.9841
# Epoch 92 ValLoss: 0.2357 ValAcc: 0.9206
#
# Epoch 93 TrainLoss: 0.0080 TrainAcc: 1.0000
# Epoch 93 ValLoss: 0.1546 ValAcc: 0.9524
#
# Epoch 94 TrainLoss: 0.0158 TrainAcc: 0.9947
# Epoch 94 ValLoss: 0.2411 ValAcc: 0.9365
#
# Epoch 95 TrainLoss: 0.1088 TrainAcc: 0.9630
# Epoch 95 ValLoss: 0.3092 ValAcc: 0.8889
#
# Epoch 96 TrainLoss: 0.0158 TrainAcc: 0.9947
# Epoch 96 ValLoss: 0.2083 ValAcc: 0.9365
#
# Epoch 97 TrainLoss: 0.0041 TrainAcc: 1.0000
# Epoch 97 ValLoss: 0.1882 ValAcc: 0.9206
#
# Epoch 98 TrainLoss: 0.0414 TrainAcc: 0.9894
# Epoch 98 ValLoss: 0.1689 ValAcc: 0.9524
#
# Epoch 99 TrainLoss: 0.0079 TrainAcc: 1.0000
# Epoch 99 ValLoss: 0.1614 ValAcc: 0.9524
#
# Epoch 100 TrainLoss: 0.0080 TrainAcc: 1.0000
# Epoch 100 ValLoss: 0.1411 ValAcc: 0.9206
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\0522Data\Weights\100\model_weights20240522_2036.pth
#
# Epoch 101 TrainLoss: 0.0235 TrainAcc: 0.9894
# Epoch 101 ValLoss: 0.1801 ValAcc: 0.9206
#
# Epoch 102 TrainLoss: 0.0446 TrainAcc: 0.9894
# Epoch 102 ValLoss: 0.1244 ValAcc: 0.9524
#
# Epoch 103 TrainLoss: 0.0130 TrainAcc: 0.9947
# Epoch 103 ValLoss: 0.0622 ValAcc: 0.9683
#
# Epoch 104 TrainLoss: 0.0439 TrainAcc: 0.9894
# Epoch 104 ValLoss: 0.0995 ValAcc: 0.9524
#
# Epoch 105 TrainLoss: 0.0072 TrainAcc: 1.0000
# Epoch 105 ValLoss: 0.0862 ValAcc: 0.9524
#
# Epoch 106 TrainLoss: 0.0047 TrainAcc: 1.0000
# Epoch 106 ValLoss: 0.1156 ValAcc: 0.9524
#
# Epoch 107 TrainLoss: 0.0031 TrainAcc: 1.0000
# Epoch 107 ValLoss: 0.0910 ValAcc: 0.9683
#
# Epoch 108 TrainLoss: 0.0318 TrainAcc: 0.9947
# Epoch 108 ValLoss: 0.1146 ValAcc: 0.9683
#
# Epoch 109 TrainLoss: 0.0110 TrainAcc: 0.9947
# Epoch 109 ValLoss: 0.0977 ValAcc: 0.9524
#
# Epoch 110 TrainLoss: 0.0122 TrainAcc: 0.9947
# Epoch 110 ValLoss: 0.1439 ValAcc: 0.9365
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\0522Data\Weights\110\model_weights20240522_2036.pth
#
# Epoch 111 TrainLoss: 0.0029 TrainAcc: 1.0000
# Epoch 111 ValLoss: 0.1177 ValAcc: 0.9365
#
# Epoch 112 TrainLoss: 0.0040 TrainAcc: 1.0000
# Epoch 112 ValLoss: 0.1527 ValAcc: 0.9365
#
# Epoch 113 TrainLoss: 0.0041 TrainAcc: 1.0000
# Epoch 113 ValLoss: 0.1349 ValAcc: 0.9365
#
# Epoch 114 TrainLoss: 0.0054 TrainAcc: 1.0000
# Epoch 114 ValLoss: 0.0836 ValAcc: 0.9524
#
# Epoch 115 TrainLoss: 0.0021 TrainAcc: 1.0000
# Epoch 115 ValLoss: 0.0883 ValAcc: 0.9524
#
# Epoch 116 TrainLoss: 0.0176 TrainAcc: 0.9947
# Epoch 116 ValLoss: 0.1307 ValAcc: 0.9365
#
# Epoch 117 TrainLoss: 0.0102 TrainAcc: 0.9947
# Epoch 117 ValLoss: 0.1197 ValAcc: 0.9683
#
# Epoch 118 TrainLoss: 0.0105 TrainAcc: 1.0000
# Epoch 118 ValLoss: 0.1742 ValAcc: 0.9365
#
# Epoch 119 TrainLoss: 0.0291 TrainAcc: 0.9894
# Epoch 119 ValLoss: 0.1621 ValAcc: 0.9206
#
# Epoch 120 TrainLoss: 0.0147 TrainAcc: 0.9947
# Epoch 120 ValLoss: 0.1295 ValAcc: 0.9524
# Saving Model...
# Model saved in C:\Users\kyohe\Aerial-Photo-Classifier\0522Data\Weights\120\model_weights20240522_2036.pth
#
# CSVs saved in C:\Users\kyohe\Aerial-Photo-Classifier\0522Data\History\20240522_2036
# Training Finished!!!
